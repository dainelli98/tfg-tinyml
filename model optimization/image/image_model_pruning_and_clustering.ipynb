# %% [markdown]
# # Image model optimization
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from joblib import dump
import matplotlib.pyplot as plt

from image_model_optimization import *

# %% [markdown]
# ## Parámetros
# Se establecen los parámetros para la optimización.

# %%
pruning = False
clustering = True

project_dir = "/home/daniel/PycharmProjects/tfg-tinyml"
saved_models_dir = f"{project_dir}/saved models/image"
original_model_name = "MicroImgDataModel"
checkpoint_dir = f"{saved_models_dir}/tensorflow/checkpoints"
original_checkpoint_path = f"{checkpoint_dir}/{original_model_name}.hdf5"
label_index_dir = f"{saved_models_dir}/label index mappings"

model_name = f"{original_model_name}Prun"
checkpoint_path = f"{checkpoint_dir}/{model_name}.hdf5"

data_dir = f"{project_dir}/samples/microcontroller/preprocessed image/train"
log_dir = f"{saved_models_dir}/summaries/{model_name}"
model_path = f"{saved_models_dir}/tensorflow/{model_name}.hdf5"

validation_percentage = 20.
initial_learning_rate = 0.001
decay = (initial_learning_rate / PRUNING_EPOCHS) * 1.5

# %% [markdown]
# ## Carga de datos
# Se cargan los mismos datasets de entrenamiento y validación que se han usado en el entrenamiento.

# %%
train_dataset, validation_dataset = get_image_datasets(data_dir, validation_percentage)
class_names = train_dataset.class_names
nclasses = len(class_names)

class_list_text = "Classes:"
for index, name in enumerate(class_names):
    class_list_text += f"\n\t{index}: {name}"

print(class_list_text)
with open(f"{label_index_dir}/{model_name}.txt", "wt") as text_file:
    text_file.write(class_list_text)

dump(class_names, f"{label_index_dir}/{model_name}.joblib")
# Out:
# Found 275 files belonging to 3 classes.
# Using 220 files for training.
# Found 275 files belonging to 3 classes.
# Using 55 files for validation.
# Classes:
# 	0: face
# 	1: mask
# 	2: nothing
# ['/home/daniel/PycharmProjects/tfg-tinyml/saved models/image/label index mappings/MicroImgDataModelPrun.joblib']

# %% [markdown]
# ## Pruning
# Se aplica pruning. Primero se carga el modelo original y luego se aplica el pruning.

# %%
def lr_time_based_decay(epoch: int, lr: float) -> float:
    """
    Callback function que reduce el learning rate conforme avanza el entrenamiento.
    Args:
        epoch:  int que representa el epoch del entrenamiento que se va a realizar a continuación.
        lr:     float con el learning rate del último epoch.

    Returns:
        float con el nuevo learning rate
    """
    return lr * 1 / (1 + decay * epoch)

model = get_image_model(nclasses, model_name)

model.load_weights(original_checkpoint_path)

model = apply_prunning(model)

model.summary()

model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, monitor='val_accuracy',
                                            mode='max', save_best_only=True, verbose=1)

early_stopping_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=PATIENCE)

callbacks = [tfmot.sparsity.keras.UpdatePruningStep(), tfmot.sparsity.keras.PruningSummaries(log_dir=log_dir),
             LearningRateScheduler(lr_time_based_decay, verbose=1), model_checkpoint_callback, early_stopping_callback]

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=PRUNING_EPOCHS,
    callbacks=callbacks
)
# Out:
# /home/daniel/.local/lib/python3.9/site-packages/tensorflow/python/keras/engine/base_layer.py:2191: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Model: "MicroImgDataModelPrun"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 96, 96, 1)         0
# _________________________________________________________________
# prune_low_magnitude_zero_pad (None, 97, 97, 1)         1
# _________________________________________________________________
# prune_low_magnitude_conv2d ( (None, 48, 48, 4)         74
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 48, 48, 4)         17
# _________________________________________________________________
# prune_low_magnitude_re_lu (P (None, 48, 48, 4)         1
# _________________________________________________________________
# prune_low_magnitude_conv2d_1 (None, 48, 48, 8)         578
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 48, 48, 8)         33
# _________________________________________________________________
# prune_low_magnitude_re_lu_1  (None, 48, 48, 8)         1
# _________________________________________________________________
# prune_low_magnitude_zero_pad (None, 49, 49, 8)         1
# _________________________________________________________________
# prune_low_magnitude_conv2d_2 (None, 24, 24, 16)        2306
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 24, 24, 16)        65
# _________________________________________________________________
# prune_low_magnitude_re_lu_2  (None, 24, 24, 16)        1
# _________________________________________________________________
# prune_low_magnitude_conv2d_3 (None, 24, 24, 16)        514
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 24, 24, 16)        65
# _________________________________________________________________
# prune_low_magnitude_re_lu_3  (None, 24, 24, 16)        1
# _________________________________________________________________
# prune_low_magnitude_zero_pad (None, 25, 25, 16)        1
# _________________________________________________________________
# prune_low_magnitude_conv2d_4 (None, 12, 12, 32)        9218
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 12, 12, 32)        129
# _________________________________________________________________
# prune_low_magnitude_re_lu_4  (None, 12, 12, 32)        1
# _________________________________________________________________
# prune_low_magnitude_conv2d_5 (None, 12, 12, 32)        2050
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 12, 12, 32)        129
# _________________________________________________________________
# prune_low_magnitude_re_lu_5  (None, 12, 12, 32)        1
# _________________________________________________________________
# prune_low_magnitude_zero_pad (None, 13, 13, 32)        1
# _________________________________________________________________
# prune_low_magnitude_conv2d_6 (None, 6, 6, 64)          36866
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 6, 6, 64)          257
# _________________________________________________________________
# prune_low_magnitude_re_lu_6  (None, 6, 6, 64)          1
# _________________________________________________________________
# prune_low_magnitude_conv2d_7 (None, 6, 6, 64)          8258
# _________________________________________________________________
# prune_low_magnitude_batch_no (None, 6, 6, 64)          257
# _________________________________________________________________
# prune_low_magnitude_re_lu_7  (None, 6, 6, 64)          1
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 3, 64)          0
# _________________________________________________________________
# prune_low_magnitude_flatten  (None, 576)               1
# _________________________________________________________________
# prune_low_magnitude_dense (P (None, 3)                 3461
# =================================================================
# Total params: 64,290
# Trainable params: 32,159
# Non-trainable params: 32,131
# _________________________________________________________________
# Epoch 1/500
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# WARNING:tensorflow:From /home/daniel/.local/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 7/7 [==============================] - 5s 131ms/step - loss: 0.7668 - accuracy: 0.6864 - val_loss: 1.4758 - val_accuracy: 0.3636
#
# Epoch 00001: val_accuracy improved from -inf to 0.36364, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 2/500
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009999970475063089.
# 7/7 [==============================] - 0s 43ms/step - loss: 0.3940 - accuracy: 0.8455 - val_loss: 1.1829 - val_accuracy: 0.5273
#
# Epoch 00002: val_accuracy improved from 0.36364 to 0.52727, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 3/500
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0009999910207529592.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2904 - accuracy: 0.8909 - val_loss: 0.9633 - val_accuracy: 0.5273
#
# Epoch 00003: val_accuracy did not improve from 0.52727
# Epoch 4/500
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009999819672646434.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.1907 - accuracy: 0.9364 - val_loss: 1.0724 - val_accuracy: 0.5091
#
# Epoch 00004: val_accuracy did not improve from 0.52727
# Epoch 5/500
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009999700034825265.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.1167 - accuracy: 0.9682 - val_loss: 1.1631 - val_accuracy: 0.5273
#
# Epoch 00005: val_accuracy did not improve from 0.52727
# Epoch 6/500
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009999550130192247.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1039 - accuracy: 0.9727 - val_loss: 1.1556 - val_accuracy: 0.5273
#
# Epoch 00006: val_accuracy did not improve from 0.52727
# Epoch 7/500
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000999936995901978.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0648 - accuracy: 0.9909 - val_loss: 1.0405 - val_accuracy: 0.5636
#
# Epoch 00007: val_accuracy improved from 0.52727 to 0.56364, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 8/500
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009999159521580257.
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0547 - accuracy: 0.9955 - val_loss: 0.9120 - val_accuracy: 0.5636
#
# Epoch 00008: val_accuracy did not improve from 0.56364
# Epoch 9/500
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009998919982271348.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0500 - accuracy: 0.9909 - val_loss: 0.9031 - val_accuracy: 0.5818
#
# Epoch 00009: val_accuracy improved from 0.56364 to 0.58182, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 10/500
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009998650177233173.
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0307 - accuracy: 0.9955 - val_loss: 0.8832 - val_accuracy: 0.6182
#
# Epoch 00010: val_accuracy improved from 0.58182 to 0.61818, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 11/500
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009998350106738118.
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.8372 - val_accuracy: 0.6364
#
# Epoch 00011: val_accuracy improved from 0.61818 to 0.63636, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 12/500
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009998019771058563.
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.7571 - val_accuracy: 0.6545
#
# Epoch 00012: val_accuracy improved from 0.63636 to 0.65455, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 13/500
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009997660334578192.
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.6755 - val_accuracy: 0.6727
#
# Epoch 00013: val_accuracy improved from 0.65455 to 0.67273, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 14/500
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009997270633451088.
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.6191 - val_accuracy: 0.7091
#
# Epoch 00014: val_accuracy improved from 0.67273 to 0.70909, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 15/500
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0009996850667949616.
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.5935 - val_accuracy: 0.7273
#
# Epoch 00015: val_accuracy improved from 0.70909 to 0.72727, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 16/500
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.000999640043834615.
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.6240 - val_accuracy: 0.7273
#
# Epoch 00016: val_accuracy did not improve from 0.72727
# Epoch 17/500
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.000999592110901039.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.6447 - val_accuracy: 0.7273
#
# Epoch 00017: val_accuracy did not improve from 0.72727
# Epoch 18/500
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009995411516110376.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.5538 - val_accuracy: 0.7273
#
# Epoch 00018: val_accuracy did not improve from 0.72727
# Epoch 19/500
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.000999487165991846.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.4921 - val_accuracy: 0.7455
#
# Epoch 00019: val_accuracy improved from 0.72727 to 0.74545, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 20/500
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009994301540707.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.4840 - val_accuracy: 0.7636
#
# Epoch 00020: val_accuracy improved from 0.74545 to 0.76364, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 21/500
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0009993702322831715.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4839 - val_accuracy: 0.7636
#
# Epoch 00021: val_accuracy did not improve from 0.76364
# Epoch 22/500
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00099930728424746.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.7636
#
# Epoch 00022: val_accuracy did not improve from 0.76364
# Epoch 23/500
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0009992413099907998.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.4114 - val_accuracy: 0.7818
#
# Epoch 00023: val_accuracy improved from 0.76364 to 0.78182, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 24/500
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.000999172309540425.
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.3572 - val_accuracy: 0.8000
#
# Epoch 00024: val_accuracy improved from 0.78182 to 0.80000, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 25/500
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00099910039933051.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.3259 - val_accuracy: 0.8182
#
# Epoch 00025: val_accuracy improved from 0.80000 to 0.81818, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 26/500
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0009990254629806492.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.3240 - val_accuracy: 0.8364
#
# Epoch 00026: val_accuracy improved from 0.81818 to 0.83636, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 27/500
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0009989475005180758.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.3427 - val_accuracy: 0.8182
#
# Epoch 00027: val_accuracy did not improve from 0.83636
# Epoch 28/500
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0009988666283759155.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.8545
#
# Epoch 00028: val_accuracy improved from 0.83636 to 0.85455, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 29/500
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0009987827301748096.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2796 - val_accuracy: 0.8727
#
# Epoch 00029: val_accuracy improved from 0.85455 to 0.87273, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 30/500
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0009986958059419902.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2427 - val_accuracy: 0.9091
#
# Epoch 00030: val_accuracy improved from 0.87273 to 0.90909, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 31/500
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0009986059721095344.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9091
#
# Epoch 00031: val_accuracy did not improve from 0.90909
# Epoch 32/500
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00099851311229913.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.9091
#
# Epoch 00032: val_accuracy did not improve from 0.90909
# Epoch 33/500
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0009984172265380081.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0088 - accuracy: 0.9955 - val_loss: 0.1946 - val_accuracy: 0.9091
#
# Epoch 00033: val_accuracy did not improve from 0.90909
# Epoch 34/500
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0009983184312571977.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9091
#
# Epoch 00034: val_accuracy did not improve from 0.90909
# Epoch 35/500
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.000998216610079433.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9273
#
# Epoch 00035: val_accuracy improved from 0.90909 to 0.92727, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 36/500
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0009981117630319444.
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9273
#
# Epoch 00036: val_accuracy did not improve from 0.92727
# Epoch 37/500
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0009980040065447116.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9273
#
# Epoch 00037: val_accuracy did not improve from 0.92727
# Epoch 38/500
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.000997893224241516.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9273
#
# Epoch 00038: val_accuracy did not improve from 0.92727
# Epoch 39/500
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0009977795325516385.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9273
#
# Epoch 00039: val_accuracy did not improve from 0.92727
# Epoch 40/500
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0009976628150995578.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9455
#
# Epoch 00040: val_accuracy improved from 0.92727 to 0.94545, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 41/500
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0009975430719125025.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9455
#
# Epoch 00041: val_accuracy did not improve from 0.94545
# Epoch 42/500
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0009974204194187052.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9455
#
# Epoch 00042: val_accuracy did not improve from 0.94545
# Epoch 43/500
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0009972947412436916.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9455
#
# Epoch 00043: val_accuracy did not improve from 0.94545
# Epoch 44/500
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0009971661538149949.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9455
#
# Epoch 00044: val_accuracy did not improve from 0.94545
# Epoch 45/500
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.000997034540758838.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9455
#
# Epoch 00045: val_accuracy did not improve from 0.94545
# Epoch 46/500
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0009968999021024482.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9455
#
# Epoch 00046: val_accuracy did not improve from 0.94545
# Epoch 47/500
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0009967623542723105.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9455
#
# Epoch 00047: val_accuracy did not improve from 0.94545
# Epoch 48/500
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0009966217808956943.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9455
#
# Epoch 00048: val_accuracy did not improve from 0.94545
# Epoch 49/500
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0009964782983983862.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9455
#
# Epoch 00049: val_accuracy did not improve from 0.94545
# Epoch 50/500
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.000996331790408353.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9455
#
# Epoch 00050: val_accuracy did not improve from 0.94545
# Epoch 51/500
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.000996182373350682.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9455
#
# Epoch 00051: val_accuracy did not improve from 0.94545
# Epoch 52/500
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.000996029930854038.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9455
#
# Epoch 00052: val_accuracy did not improve from 0.94545
# Epoch 53/500
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0009958745793428097.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9455
#
# Epoch 00053: val_accuracy did not improve from 0.94545
# Epoch 54/500
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0009957162024463594.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9455
#
# Epoch 00054: val_accuracy did not improve from 0.94545
# Epoch 55/500
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0009955549165883764.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9636
#
# Epoch 00055: val_accuracy improved from 0.94545 to 0.96364, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/checkpoints/MicroImgDataModelPrun.hdf5
# Epoch 56/500
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0009953907217950372.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9636
#
# Epoch 00056: val_accuracy did not improve from 0.96364
# Epoch 57/500
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0009952235016967507.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9636
#
# Epoch 00057: val_accuracy did not improve from 0.96364
# Epoch 58/500
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0009950533727161577.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9636
#
# Epoch 00058: val_accuracy did not improve from 0.96364
# Epoch 59/500
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.000994880218484365.
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9455
#
# Epoch 00059: val_accuracy did not improve from 0.96364
# Epoch 60/500
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0009947041554233145.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9455
#
# Epoch 00060: val_accuracy did not improve from 0.96364
# Epoch 61/500
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0009945251835591815.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9455
#
# Epoch 00061: val_accuracy did not improve from 0.96364
# Epoch 62/500
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0009943431865241184.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9455
#
# Epoch 00062: val_accuracy did not improve from 0.96364
# Epoch 63/500
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0009941582807390195.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1091 - val_accuracy: 0.9455
#
# Epoch 00063: val_accuracy did not improve from 0.96364
# Epoch 64/500
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0009939704662300583.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9455
#
# Epoch 00064: val_accuracy did not improve from 0.96364
# Epoch 65/500
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.000993779626630434.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9455
#
# Epoch 00065: val_accuracy did not improve from 0.96364
# Epoch 66/500
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0009935858783599926.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9455
#
# Epoch 00066: val_accuracy did not improve from 0.96364
# Epoch 67/500
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0009933892214449066.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9455
#
# Epoch 00067: val_accuracy did not improve from 0.96364
# Epoch 68/500
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0009931895395194218.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9455
#
# Epoch 00068: val_accuracy did not improve from 0.96364
# Epoch 69/500
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0009929869490023354.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9455
#
# Epoch 00069: val_accuracy did not improve from 0.96364
# Epoch 70/500
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0009927814499198196.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9636
#
# Epoch 00070: val_accuracy did not improve from 0.96364
# Epoch 71/500
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.000992573042298046.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9636
#
# Epoch 00071: val_accuracy did not improve from 0.96364
# Epoch 72/500
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.0009923617261631856.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9636
#
# Epoch 00072: val_accuracy did not improve from 0.96364
# Epoch 73/500
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.000992147385151228.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9636
#
# Epoch 00073: val_accuracy did not improve from 0.96364
# Epoch 74/500
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0009919301356792235.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9636
#
# Epoch 00074: val_accuracy did not improve from 0.96364
# Epoch 75/500
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0009917099777733425.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9636
#
# Epoch 00075: val_accuracy did not improve from 0.96364
# Epoch 76/500
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.000991486911459755.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9636
#
# Epoch 00076: val_accuracy did not improve from 0.96364
# Epoch 77/500
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0009912609367646308.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9636
#
# Epoch 00077: val_accuracy did not improve from 0.96364
# Epoch 78/500
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0009910320537141388.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9455
#
# Epoch 00078: val_accuracy did not improve from 0.96364
# Epoch 79/500
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.0009908002623344489.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9455
#
# Epoch 00079: val_accuracy did not improve from 0.96364
# Epoch 80/500
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0009905654462639914.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9455
#
# Epoch 00080: val_accuracy did not improve from 0.96364
# Epoch 81/500
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0009903277219173708.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9455
#
# Epoch 00081: val_accuracy did not improve from 0.96364
# Epoch 82/500
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.0009900870893207554.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9455
#
# Epoch 00082: val_accuracy did not improve from 0.96364
# Epoch 83/500
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0009898435485003131.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9455
#
# Epoch 00083: val_accuracy did not improve from 0.96364
# Epoch 84/500
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0009895970994822111.
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9455
#
# Epoch 00084: val_accuracy did not improve from 0.96364
# Epoch 85/500
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.000989347742292617.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9455
#
# Epoch 00085: val_accuracy did not improve from 0.96364
# Epoch 86/500
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0009890954769576972.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9455
#
# Epoch 00086: val_accuracy did not improve from 0.96364
# Epoch 87/500
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0009888403035036182.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9455
#
# Epoch 00087: val_accuracy did not improve from 0.96364
# Epoch 88/500
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0009885823383414924.
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9455
#
# Epoch 00088: val_accuracy did not improve from 0.96364
# Epoch 89/500
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0009883214651118415.
# 7/7 [==============================] - 0s 38ms/step - loss: 6.7575e-04 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9455
#
# Epoch 00089: val_accuracy did not improve from 0.96364
# Epoch 90/500
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.0009880576838408313.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9636
#
# Epoch 00090: val_accuracy did not improve from 0.96364
# Epoch 91/500
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0009877909945546273.
# 7/7 [==============================] - 0s 38ms/step - loss: 8.9814e-04 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9636
#
# Epoch 00091: val_accuracy did not improve from 0.96364
# Epoch 92/500
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0009875213972793944.
# 7/7 [==============================] - 0s 39ms/step - loss: 8.2199e-04 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9636
#
# Epoch 00092: val_accuracy did not improve from 0.96364
# Epoch 93/500
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.000987248892041297.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9636
#
# Epoch 00093: val_accuracy did not improve from 0.96364
# Epoch 94/500
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0009869734788664998.
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9636
#
# Epoch 00094: val_accuracy did not improve from 0.96364
# Epoch 95/500
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0009866952741636687.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9636
#
# Epoch 00095: val_accuracy did not improve from 0.96364
# Epoch 96/500
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0009864141615757672.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9636
#
# Epoch 00096: val_accuracy did not improve from 0.96364
# Epoch 97/500
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0009861301411289592.
# 7/7 [==============================] - 0s 37ms/step - loss: 7.3597e-04 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9636
#
# Epoch 00097: val_accuracy did not improve from 0.96364
# Epoch 98/500
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0009858432128494075.
# 7/7 [==============================] - 0s 38ms/step - loss: 6.0386e-04 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 0.9455
#
# Epoch 00098: val_accuracy did not improve from 0.96364
# Epoch 99/500
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0009855534931443807.
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9455
#
# Epoch 00099: val_accuracy did not improve from 0.96364
# Epoch 100/500
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0009852608656582373.
# 7/7 [==============================] - 0s 36ms/step - loss: 5.1375e-04 - accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9455
#
# Epoch 00100: val_accuracy did not improve from 0.96364
# Epoch 101/500
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 0.0009849653304171398.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9455
#
# Epoch 00101: val_accuracy did not improve from 0.96364
# Epoch 102/500
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 0.0009846670038273085.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9636
#
# Epoch 00102: val_accuracy did not improve from 0.96364
# Epoch 103/500
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 0.0009843657695341483.
# 7/7 [==============================] - 0s 38ms/step - loss: 7.2228e-04 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9636
#
# Epoch 00103: val_accuracy did not improve from 0.96364
# Epoch 104/500
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 0.0009840617439431812.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9636
#
# Epoch 00104: val_accuracy did not improve from 0.96364
# Epoch 105/500
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 0.0009837548107005088.
# 7/7 [==============================] - 0s 36ms/step - loss: 9.8481e-04 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9636
#
# Epoch 00105: val_accuracy did not improve from 0.96364
# Epoch 106/500
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 0.0009834449698322926.
# 7/7 [==============================] - 0s 39ms/step - loss: 7.0600e-04 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9636
#
# Epoch 00106: val_accuracy did not improve from 0.96364
# Epoch 107/500
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 0.0009831323377430061.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9636
#
# Epoch 00107: val_accuracy did not improve from 0.96364
# Epoch 108/500
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 0.0009828167980797976.
# 7/7 [==============================] - 0s 37ms/step - loss: 5.7549e-04 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9636
#
# Epoch 00108: val_accuracy did not improve from 0.96364
# Epoch 109/500
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 0.0009824984672464423.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9636
#
# Epoch 00109: val_accuracy did not improve from 0.96364
# Epoch 110/500
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.0009821773452680527.
# 7/7 [==============================] - 0s 39ms/step - loss: 8.0213e-04 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9636
#
# Epoch 00110: val_accuracy did not improve from 0.96364
# Epoch 111/500
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.0009818533157928233.
# 7/7 [==============================] - 0s 38ms/step - loss: 9.8530e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9636
#
# Epoch 00111: val_accuracy did not improve from 0.96364
# Epoch 112/500
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.0009815264952234813.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9636
#
# Epoch 00112: val_accuracy did not improve from 0.96364
# Epoch 113/500
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.0009811967672089185.
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9636
#
# Epoch 00113: val_accuracy did not improve from 0.96364
# Epoch 114/500
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.0009808642481511634.
# 7/7 [==============================] - 0s 38ms/step - loss: 6.2113e-04 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9636
#
# Epoch 00114: val_accuracy did not improve from 0.96364
# Epoch 115/500
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.000980528938075327.
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9636
#
# Epoch 00115: val_accuracy did not improve from 0.96364
# Epoch 116/500
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.0009801907206313477.
# 7/7 [==============================] - 0s 38ms/step - loss: 6.7382e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9636
#
# Epoch 00116: val_accuracy did not improve from 0.96364
# Epoch 117/500
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.0009798497122202056.
# 7/7 [==============================] - 0s 36ms/step - loss: 7.4212e-04 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9636
#
# Epoch 00117: val_accuracy did not improve from 0.96364
# Epoch 118/500
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.0009795059128670108.
# 7/7 [==============================] - 0s 37ms/step - loss: 8.6147e-04 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9636
#
# Epoch 00118: val_accuracy did not improve from 0.96364
# Epoch 119/500
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.0009791593225968729.
# 7/7 [==============================] - 0s 38ms/step - loss: 5.5161e-04 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9636
#
# Epoch 00119: val_accuracy did not improve from 0.96364
# Epoch 120/500
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.0009788099414349011.
# 7/7 [==============================] - 0s 37ms/step - loss: 5.7682e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9636
#
# Epoch 00120: val_accuracy did not improve from 0.96364
# Epoch 121/500
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.0009784576530327772.
# 7/7 [==============================] - 0s 36ms/step - loss: 7.7581e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9636
#
# Epoch 00121: val_accuracy did not improve from 0.96364
# Epoch 122/500
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.0009781025737897351.
# 7/7 [==============================] - 0s 37ms/step - loss: 8.4674e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9636
#
# Epoch 00122: val_accuracy did not improve from 0.96364
# Epoch 123/500
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.000977744703730883.
# 7/7 [==============================] - 0s 37ms/step - loss: 7.7716e-04 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9636
#
# Epoch 00123: val_accuracy did not improve from 0.96364
# Epoch 124/500
#
# Epoch 00124: LearningRateScheduler reducing learning rate to 0.0009773840428813293.
# 7/7 [==============================] - 0s 37ms/step - loss: 5.2328e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9636
#
# Epoch 00124: val_accuracy did not improve from 0.96364
# Epoch 00124: early stopping

# %% [markdown]
# ## Visualización de historial de entrenamiento
#
# Se visualiza accuracy y loss de training y validation.

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title(f"Training and Validation Accuracy\nfor {model_name}")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.title(f"Training and Validation Loss\nfor {model_name}")

plt.savefig(f"{log_dir}/{model_name}_training_data.jpg")

plt.show()

# %% [markdown]
# ## Guardar modelo
# Guardamos el modelo entrenado para poder reutilizarlo en el futuro.

# %%
tf.keras.models.save_model(model, model_path, save_format="h5")
# Out:
# WARNING:absl:Found untraced functions such as conv2d_layer_call_and_return_conditional_losses, conv2d_layer_call_fn, re_lu_layer_call_and_return_conditional_losses, re_lu_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses while saving (showing 5 of 90). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/MicroImgDataModelPrun/assets
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/image/tensorflow/MicroImgDataModelPrun/assets
