# %% [markdown]
# # Audio quantization aware training
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from joblib import dump
import matplotlib.pyplot as plt

from audio_model_optimization import *
from audio_model_training import get_audio_datasets, CLASS_NAMES, NCLASSES, get_audio_model

# %% [markdown]
# ## Parámetros
# Se establecen los parámetros para la optimización.

# %%
project_dir = "/home/daniel/PycharmProjects/tfg-tinyml"
saved_models_dir = f"{project_dir}/saved models/audio"
original_model_name = "ExtAudioDataModel"
checkpoint_dir = f"{saved_models_dir}/tensorflow/checkpoints"
label_index_dir = f"{saved_models_dir}/label index mappings"

model_name = f"{original_model_name}QAT"
checkpoint_path = f"{checkpoint_dir}/{model_name}.hdf5"

data_dir = f"{project_dir}/samples/external/audio/train"
log_dir = f"{saved_models_dir}/summaries/{model_name}"
model_dir = f"{saved_models_dir}/tensorflow/{model_name}"

validation_percentage = 20.
initial_learning_rate = 0.001
decay = (initial_learning_rate / QUANT_EPOCHS) * 1.5

# %% [markdown]
# ## Carga de datos
# Se cargan los mismos datasets de entrenamiento y validación que se han usado en el entrenamiento.

# %%
train_dataset, validation_dataset = get_audio_datasets(data_dir, validation_percentage)

class_list_text = "Classes:"
for index, name in enumerate(CLASS_NAMES):
    class_list_text += f"\n\t{index}: {name}"

print(class_list_text)
with open(f"{label_index_dir}/{model_name}.txt", "wt") as text_file:
    text_file.write(class_list_text)

dump(CLASS_NAMES, f"{label_index_dir}/{model_name}.joblib")

train_dataset = normalize_dataset(train_dataset)
validation_dataset = normalize_dataset(validation_dataset)
# Out:
# Se usarán 12924 muestras:
# 	- Train: 10340
# 	- Validation: 2584
# WARNING:tensorflow:From /home/daniel/.local/lib/python3.8/site-packages/tensorflow/python/ops/parallel_for/pfor.py:2380: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# Classes:
# 	0: no
# 	1: silence
# 	2: unknown
# 	3: yes

# %% [markdown]
# ## Quantization aware training
# Se reentrena el modelo usando quantization aware training.

# %%
model = get_audio_model((40, 49, 1), model_name, train_dataset, normalize=False)

model = tfmot.quantization.keras.quantize_model(model)

def lr_time_based_decay(epoch: int, lr: float) -> float:
    """
    Callback function que reduce el learning rate conforme avanza el entrenamiento.
    Args:
        epoch:  int que representa el epoch del entrenamiento que se va a realizar a continuación.
        lr:     float con el learning rate del último epoch.

    Returns:
        float con el nuevo learning rate
    """
    return lr * 1 / (1 + decay * epoch)

model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, monitor='val_accuracy',
                                            mode='max', save_best_only=True, verbose=1)

early_stopping_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=QUANT_PATIENCE)

callbacks = [LearningRateScheduler(lr_time_based_decay, verbose=1), model_checkpoint_callback, early_stopping_callback]

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=QUANT_EPOCHS,
    callbacks=callbacks
)

model.load_weights(checkpoint_path)
# Out:
# Model: "ExtAudioDataModelQAT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quantize_layer (QuantizeLaye (None, 40, 49, 1)         3
# _________________________________________________________________
# quant_conv2d (QuantizeWrappe (None, 17, 20, 8)         667
# _________________________________________________________________
# quant_max_pooling2d (Quantiz (None, 8, 10, 8)          1
# _________________________________________________________________
# quant_dropout (QuantizeWrapp (None, 8, 10, 8)          1
# _________________________________________________________________
# quant_flatten (QuantizeWrapp (None, 640)               1
# _________________________________________________________________
# quant_dense (QuantizeWrapper (None, 4)                 2569
# =================================================================
# Total params: 3,242
# Trainable params: 3,212
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 324/324 [==============================] - 3s 7ms/step - loss: 0.7575 - accuracy: 0.6769 - val_loss: 0.5083 - val_accuracy: 0.8007
#
# Epoch 00001: val_accuracy improved from -inf to 0.80070, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 2/250
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009999940475331661.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.4559 - accuracy: 0.8203 - val_loss: 0.3983 - val_accuracy: 0.8487
#
# Epoch 00002: val_accuracy improved from 0.80070 to 0.84868, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 3/250
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000999981994116787.
# 324/324 [==============================] - 2s 7ms/step - loss: 0.3751 - accuracy: 0.8564 - val_loss: 0.3309 - val_accuracy: 0.8835
#
# Epoch 00003: val_accuracy improved from 0.84868 to 0.88351, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 4/250
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009999640037705003.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3416 - accuracy: 0.8696 - val_loss: 0.3131 - val_accuracy: 0.8854
#
# Epoch 00004: val_accuracy improved from 0.88351 to 0.88545, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 5/250
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009999399601886404.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3209 - accuracy: 0.8788 - val_loss: 0.2922 - val_accuracy: 0.8978
#
# Epoch 00005: val_accuracy improved from 0.88545 to 0.89783, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 6/250
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.000999909979891992.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2998 - accuracy: 0.8852 - val_loss: 0.2731 - val_accuracy: 0.9056
#
# Epoch 00006: val_accuracy improved from 0.89783 to 0.90557, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 7/250
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009998739465762805.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2922 - accuracy: 0.8923 - val_loss: 0.2605 - val_accuracy: 0.9137
#
# Epoch 00007: val_accuracy improved from 0.90557 to 0.91370, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 8/250
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009998319767608886.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2777 - accuracy: 0.8956 - val_loss: 0.2640 - val_accuracy: 0.9098
#
# Epoch 00008: val_accuracy did not improve from 0.91370
# Epoch 9/250
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009997839541429343.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2733 - accuracy: 0.8950 - val_loss: 0.2599 - val_accuracy: 0.9102
#
# Epoch 00009: val_accuracy did not improve from 0.91370
# Epoch 10/250
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009997299952403975.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2606 - accuracy: 0.9014 - val_loss: 0.2435 - val_accuracy: 0.9160
#
# Epoch 00010: val_accuracy improved from 0.91370 to 0.91602, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 11/250
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009996699837517878.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2536 - accuracy: 0.9043 - val_loss: 0.2391 - val_accuracy: 0.9160
#
# Epoch 00011: val_accuracy did not improve from 0.91602
# Epoch 12/250
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009996040361936833.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2535 - accuracy: 0.9039 - val_loss: 0.2348 - val_accuracy: 0.9160
#
# Epoch 00012: val_accuracy did not improve from 0.91602
# Epoch 13/250
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009995320362659848.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2403 - accuracy: 0.9084 - val_loss: 0.2332 - val_accuracy: 0.9191
#
# Epoch 00013: val_accuracy improved from 0.91602 to 0.91912, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 14/250
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009994541004838694.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2358 - accuracy: 0.9088 - val_loss: 0.2227 - val_accuracy: 0.9226
#
# Epoch 00014: val_accuracy improved from 0.91912 to 0.92260, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 15/250
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.000999370112548629.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2328 - accuracy: 0.9104 - val_loss: 0.2217 - val_accuracy: 0.9261
#
# Epoch 00015: val_accuracy improved from 0.92260 to 0.92608, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 16/250
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009992801889740382.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2287 - accuracy: 0.9147 - val_loss: 0.2185 - val_accuracy: 0.9218
#
# Epoch 00016: val_accuracy did not improve from 0.92608
# Epoch 17/250
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.000999184213462781.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2231 - accuracy: 0.9176 - val_loss: 0.2114 - val_accuracy: 0.9241
#
# Epoch 00017: val_accuracy did not improve from 0.92608
# Epoch 18/250
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009990823025272304.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2222 - accuracy: 0.9169 - val_loss: 0.2151 - val_accuracy: 0.9214
#
# Epoch 00018: val_accuracy did not improve from 0.92608
# Epoch 19/250
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.000998974456274212.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2145 - accuracy: 0.9169 - val_loss: 0.2081 - val_accuracy: 0.9253
#
# Epoch 00019: val_accuracy did not improve from 0.92608
# Epoch 20/250
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009988605584084975.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2145 - accuracy: 0.9208 - val_loss: 0.1997 - val_accuracy: 0.9265
#
# Epoch 00020: val_accuracy improved from 0.92608 to 0.92647, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 21/250
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0009987407254403566.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2099 - accuracy: 0.9200 - val_loss: 0.2036 - val_accuracy: 0.9269
#
# Epoch 00021: val_accuracy improved from 0.92647 to 0.92686, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 22/250
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0009986149574766072.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2083 - accuracy: 0.9207 - val_loss: 0.2015 - val_accuracy: 0.9296
#
# Epoch 00022: val_accuracy improved from 0.92686 to 0.92957, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 23/250
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000998483138224109.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2041 - accuracy: 0.9232 - val_loss: 0.2029 - val_accuracy: 0.9261
#
# Epoch 00023: val_accuracy did not improve from 0.92957
# Epoch 24/250
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.000998345384191028.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.2022 - accuracy: 0.9237 - val_loss: 0.1968 - val_accuracy: 0.9303
#
# Epoch 00024: val_accuracy improved from 0.92957 to 0.93034, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 25/250
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0009982016954841755.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1986 - accuracy: 0.9243 - val_loss: 0.1909 - val_accuracy: 0.9307
#
# Epoch 00025: val_accuracy improved from 0.93034 to 0.93073, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 26/250
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0009980519558124969.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1931 - accuracy: 0.9269 - val_loss: 0.1921 - val_accuracy: 0.9327
#
# Epoch 00026: val_accuracy improved from 0.93073 to 0.93266, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 27/250
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0009978962816820569.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1959 - accuracy: 0.9266 - val_loss: 0.1906 - val_accuracy: 0.9284
#
# Epoch 00027: val_accuracy did not improve from 0.93266
# Epoch 28/250
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0009977346731996585.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1984 - accuracy: 0.9248 - val_loss: 0.1965 - val_accuracy: 0.9300
#
# Epoch 00028: val_accuracy did not improve from 0.93266
# Epoch 29/250
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0009975671304721016.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1961 - accuracy: 0.9261 - val_loss: 0.1878 - val_accuracy: 0.9334
#
# Epoch 00029: val_accuracy improved from 0.93266 to 0.93344, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 30/250
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0009973935372111155.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1883 - accuracy: 0.9262 - val_loss: 0.1940 - val_accuracy: 0.9327
#
# Epoch 00030: val_accuracy did not improve from 0.93344
# Epoch 31/250
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0009972140099199606.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1859 - accuracy: 0.9297 - val_loss: 0.1881 - val_accuracy: 0.9315
#
# Epoch 00031: val_accuracy did not improve from 0.93344
# Epoch 32/250
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00099702854870543.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1887 - accuracy: 0.9273 - val_loss: 0.1836 - val_accuracy: 0.9342
#
# Epoch 00032: val_accuracy improved from 0.93344 to 0.93421, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 33/250
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0009968371536743133.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1813 - accuracy: 0.9323 - val_loss: 0.1899 - val_accuracy: 0.9323
#
# Epoch 00033: val_accuracy did not improve from 0.93421
# Epoch 34/250
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0009966398249333986.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1887 - accuracy: 0.9299 - val_loss: 0.1876 - val_accuracy: 0.9361
#
# Epoch 00034: val_accuracy improved from 0.93421 to 0.93615, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 35/250
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0009964365625894703.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1890 - accuracy: 0.9301 - val_loss: 0.1899 - val_accuracy: 0.9323
#
# Epoch 00035: val_accuracy did not improve from 0.93615
# Epoch 36/250
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0009962273667493114.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1842 - accuracy: 0.9293 - val_loss: 0.1843 - val_accuracy: 0.9338
#
# Epoch 00036: val_accuracy did not improve from 0.93615
# Epoch 37/250
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0009960122375197015.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1806 - accuracy: 0.9333 - val_loss: 0.1931 - val_accuracy: 0.9323
#
# Epoch 00037: val_accuracy did not improve from 0.93615
# Epoch 38/250
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.000995791175007418.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1813 - accuracy: 0.9324 - val_loss: 0.1839 - val_accuracy: 0.9311
#
# Epoch 00038: val_accuracy did not improve from 0.93615
# Epoch 39/250
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0009955641793192357.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1730 - accuracy: 0.9331 - val_loss: 0.1896 - val_accuracy: 0.9319
#
# Epoch 00039: val_accuracy did not improve from 0.93615
# Epoch 40/250
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0009953312505619261.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1796 - accuracy: 0.9323 - val_loss: 0.1849 - val_accuracy: 0.9338
#
# Epoch 00040: val_accuracy did not improve from 0.93615
# Epoch 41/250
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00099509238884226.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1766 - accuracy: 0.9347 - val_loss: 0.1787 - val_accuracy: 0.9354
#
# Epoch 00041: val_accuracy did not improve from 0.93615
# Epoch 42/250
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0009948477106536942.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1683 - accuracy: 0.9361 - val_loss: 0.1846 - val_accuracy: 0.9338
#
# Epoch 00042: val_accuracy did not improve from 0.93615
# Epoch 43/250
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0009945970997149067.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1732 - accuracy: 0.9343 - val_loss: 0.1832 - val_accuracy: 0.9354
#
# Epoch 00043: val_accuracy did not improve from 0.93615
# Epoch 44/250
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.000994340556132659.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1672 - accuracy: 0.9362 - val_loss: 0.1832 - val_accuracy: 0.9369
#
# Epoch 00044: val_accuracy improved from 0.93615 to 0.93692, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 45/250
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0009940780800137112.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1745 - accuracy: 0.9359 - val_loss: 0.1840 - val_accuracy: 0.9350
#
# Epoch 00045: val_accuracy did not improve from 0.93692
# Epoch 46/250
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.000993809787848718.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1654 - accuracy: 0.9376 - val_loss: 0.1885 - val_accuracy: 0.9365
#
# Epoch 00046: val_accuracy did not improve from 0.93692
# Epoch 47/250
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0009935355633591389.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1661 - accuracy: 0.9364 - val_loss: 0.1863 - val_accuracy: 0.9365
#
# Epoch 00047: val_accuracy did not improve from 0.93692
# Epoch 48/250
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0009932555230342279.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1698 - accuracy: 0.9342 - val_loss: 0.1901 - val_accuracy: 0.9346
#
# Epoch 00048: val_accuracy did not improve from 0.93692
# Epoch 49/250
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.000992969550596836.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1686 - accuracy: 0.9351 - val_loss: 0.1770 - val_accuracy: 0.9389
#
# Epoch 00049: val_accuracy improved from 0.93692 to 0.93885, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 50/250
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.00099267764615371.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1686 - accuracy: 0.9359 - val_loss: 0.1779 - val_accuracy: 0.9389
#
# Epoch 00050: val_accuracy did not improve from 0.93885
# Epoch 51/250
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0009923799261920014.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1603 - accuracy: 0.9382 - val_loss: 0.1865 - val_accuracy: 0.9354
#
# Epoch 00051: val_accuracy did not improve from 0.93885
# Epoch 52/250
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0009920763908163577.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1691 - accuracy: 0.9364 - val_loss: 0.1798 - val_accuracy: 0.9381
#
# Epoch 00052: val_accuracy did not improve from 0.93885
# Epoch 53/250
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.000991766923752412.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1613 - accuracy: 0.9378 - val_loss: 0.1802 - val_accuracy: 0.9373
#
# Epoch 00053: val_accuracy did not improve from 0.93885
# Epoch 54/250
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0009914516414852145.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1618 - accuracy: 0.9388 - val_loss: 0.1748 - val_accuracy: 0.9392
#
# Epoch 00054: val_accuracy improved from 0.93885 to 0.93924, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 55/250
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0009911305441194047.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1597 - accuracy: 0.9407 - val_loss: 0.1853 - val_accuracy: 0.9377
#
# Epoch 00055: val_accuracy did not improve from 0.93924
# Epoch 56/250
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0009908036317596203.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1566 - accuracy: 0.9419 - val_loss: 0.1814 - val_accuracy: 0.9377
#
# Epoch 00056: val_accuracy did not improve from 0.93924
# Epoch 57/250
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.000990470788134276.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1558 - accuracy: 0.9396 - val_loss: 0.1821 - val_accuracy: 0.9377
#
# Epoch 00057: val_accuracy did not improve from 0.93924
# Epoch 58/250
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0009901321297256195.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1572 - accuracy: 0.9391 - val_loss: 0.1716 - val_accuracy: 0.9377
#
# Epoch 00058: val_accuracy did not improve from 0.93924
# Epoch 59/250
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.000989787656638281.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1597 - accuracy: 0.9394 - val_loss: 0.1794 - val_accuracy: 0.9365
#
# Epoch 00059: val_accuracy did not improve from 0.93924
# Epoch 60/250
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0009894373689768876.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1542 - accuracy: 0.9441 - val_loss: 0.1839 - val_accuracy: 0.9358
#
# Epoch 00060: val_accuracy did not improve from 0.93924
# Epoch 61/250
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0009890812668460636.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1555 - accuracy: 0.9429 - val_loss: 0.1865 - val_accuracy: 0.9385
#
# Epoch 00061: val_accuracy did not improve from 0.93924
# Epoch 62/250
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.000988719350350431.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1578 - accuracy: 0.9394 - val_loss: 0.1927 - val_accuracy: 0.9342
#
# Epoch 00062: val_accuracy did not improve from 0.93924
# Epoch 63/250
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0009883517359666417.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1574 - accuracy: 0.9397 - val_loss: 0.1808 - val_accuracy: 0.9385
#
# Epoch 00063: val_accuracy did not improve from 0.93924
# Epoch 64/250
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.000987978307425885.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1526 - accuracy: 0.9406 - val_loss: 0.1852 - val_accuracy: 0.9373
#
# Epoch 00064: val_accuracy did not improve from 0.93924
# Epoch 65/250
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0009875990648327752.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1596 - accuracy: 0.9411 - val_loss: 0.1833 - val_accuracy: 0.9377
#
# Epoch 00065: val_accuracy did not improve from 0.93924
# Epoch 66/250
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0009872140082919252.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1555 - accuracy: 0.9415 - val_loss: 0.1783 - val_accuracy: 0.9389
#
# Epoch 00066: val_accuracy did not improve from 0.93924
# Epoch 67/250
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0009868232542771835.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1543 - accuracy: 0.9431 - val_loss: 0.1783 - val_accuracy: 0.9389
#
# Epoch 00067: val_accuracy did not improve from 0.93924
# Epoch 68/250
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.000986426686522522.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1539 - accuracy: 0.9419 - val_loss: 0.1795 - val_accuracy: 0.9358
#
# Epoch 00068: val_accuracy did not improve from 0.93924
# Epoch 69/250
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0009860244215003896.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1552 - accuracy: 0.9404 - val_loss: 0.1822 - val_accuracy: 0.9373
#
# Epoch 00069: val_accuracy did not improve from 0.93924
# Epoch 70/250
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0009856163429461482.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1553 - accuracy: 0.9420 - val_loss: 0.1852 - val_accuracy: 0.9385
#
# Epoch 00070: val_accuracy did not improve from 0.93924
# Epoch 71/250
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0009852025673308454.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1564 - accuracy: 0.9395 - val_loss: 0.1726 - val_accuracy: 0.9404
#
# Epoch 00071: val_accuracy improved from 0.93924 to 0.94040, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 72/250
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.000984783094756985.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1500 - accuracy: 0.9448 - val_loss: 0.1850 - val_accuracy: 0.9400
#
# Epoch 00072: val_accuracy did not improve from 0.94040
# Epoch 73/250
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0009843578089620156.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1531 - accuracy: 0.9430 - val_loss: 0.1913 - val_accuracy: 0.9350
#
# Epoch 00073: val_accuracy did not improve from 0.94040
# Epoch 74/250
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0009839268264148838.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1511 - accuracy: 0.9425 - val_loss: 0.1808 - val_accuracy: 0.9361
#
# Epoch 00074: val_accuracy did not improve from 0.94040
# Epoch 75/250
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0009834901472180852.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1534 - accuracy: 0.9414 - val_loss: 0.1760 - val_accuracy: 0.9404
#
# Epoch 00075: val_accuracy did not improve from 0.94040
# Epoch 76/250
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0009830477714741139.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1526 - accuracy: 0.9416 - val_loss: 0.1965 - val_accuracy: 0.9354
#
# Epoch 00076: val_accuracy did not improve from 0.94040
# Epoch 77/250
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0009825996992854607.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1493 - accuracy: 0.9438 - val_loss: 0.1810 - val_accuracy: 0.9385
#
# Epoch 00077: val_accuracy did not improve from 0.94040
# Epoch 78/250
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0009821459307546145.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.1524 - accuracy: 0.9416 - val_loss: 0.1782 - val_accuracy: 0.9392
#
# Epoch 00078: val_accuracy did not improve from 0.94040
# Epoch 00078: early stopping

# %% [markdown]
# ## Visualización de historial de entrenamiento
#
# Se visualiza accuracy y loss de training y validation.

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title(f"Training and Validation Accuracy\nfor {model_name}")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.title(f"Training and Validation Loss\nfor {model_name}")

plt.savefig(f"{log_dir}/{model_name}_training_data.jpg")

plt.show()

# %% [markdown]
# ## Guardar modelo
# Guardamos el modelo entrenado para poder reutilizarlo en el futuro.

# %%
tf.keras.models.save_model(model, model_dir)
# Out:
# WARNING:absl:Found untraced functions such as conv2d_layer_call_fn, conv2d_layer_call_and_return_conditional_losses, dropout_layer_call_fn, dropout_layer_call_and_return_conditional_losses, flatten_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
