# %% [markdown]
# # Audio quantization aware training
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from joblib import dump
import matplotlib.pyplot as plt

from audio_model_optimization import *
from audio_model_training import get_audio_datasets, CLASS_NAMES, NCLASSES, get_audio_model

# %% [markdown]
# ## Parámetros
# Se establecen los parámetros para la optimización.

# %%
project_dir = "/home/daniel/PycharmProjects/tfg-tinyml"
saved_models_dir = f"{project_dir}/saved models/audio"
original_model_name = "ExtAudioDataModel"
checkpoint_dir = f"{saved_models_dir}/tensorflow/checkpoints"
label_index_dir = f"{saved_models_dir}/label index mappings"

model_name = f"{original_model_name}QAT"
checkpoint_path = f"{checkpoint_dir}/{model_name}.hdf5"

data_dir = f"{project_dir}/samples/external/audio/train"
log_dir = f"{saved_models_dir}/summaries/{model_name}"
model_dir = f"{saved_models_dir}/tensorflow/{model_name}"

validation_percentage = 20.
initial_learning_rate = 0.001
decay = (initial_learning_rate / QUANT_EPOCHS) * 1.5

# %% [markdown]
# ## Carga de datos
# Se cargan los mismos datasets de entrenamiento y validación que se han usado en el entrenamiento.

# %%
train_dataset, validation_dataset = get_audio_datasets(data_dir, validation_percentage)

class_list_text = "Classes:"
for index, name in enumerate(CLASS_NAMES):
    class_list_text += f"\n\t{index}: {name}"

print(class_list_text)
with open(f"{label_index_dir}/{model_name}.txt", "wt") as text_file:
    text_file.write(class_list_text)

dump(CLASS_NAMES, f"{label_index_dir}/{model_name}.joblib")

# Estas operaciones no se pueden aplicar a los datos en el microcontrolador.
# train_dataset = normalize_dataset(train_dataset)
# validation_dataset = normalize_dataset(validation_dataset)
# Out:
# Se usarán 12924 muestras:
# 	- Train: 10340
# 	- Validation: 2584
# WARNING:tensorflow:From /home/daniel/.local/lib/python3.8/site-packages/tensorflow/python/ops/parallel_for/pfor.py:2380: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# Classes:
# 	0: no
# 	1: silence
# 	2: unknown
# 	3: yes
# ['/home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/label index mappings/ExtAudioDataModelQAT.joblib']

# %% [markdown]
# ## Quantization aware training
# Se reentrena el modelo usando quantization aware training.

# %%
model = get_audio_model((40, 49, 1), model_name, train_dataset, normalize=False)

model = tfmot.quantization.keras.quantize_model(model)

def lr_time_based_decay(epoch: int, lr: float) -> float:
    """
    Callback function que reduce el learning rate conforme avanza el entrenamiento.
    Args:
        epoch:  int que representa el epoch del entrenamiento que se va a realizar a continuación.
        lr:     float con el learning rate del último epoch.

    Returns:
        float con el nuevo learning rate
    """
    return lr * 1 / (1 + decay * epoch)

model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, monitor='val_accuracy',
                                            mode='max', save_best_only=True, verbose=1)

early_stopping_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=QUANT_PATIENCE)

callbacks = [LearningRateScheduler(lr_time_based_decay, verbose=1), model_checkpoint_callback, early_stopping_callback]

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=QUANT_EPOCHS,
    callbacks=callbacks
)

model.load_weights(checkpoint_path)
# Out:
# Model: "ExtAudioDataModelQAT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quantize_layer (QuantizeLaye (None, 40, 49, 1)         3
# _________________________________________________________________
# quant_conv2d (QuantizeWrappe (None, 17, 20, 8)         667
# _________________________________________________________________
# quant_max_pooling2d (Quantiz (None, 8, 10, 8)          1
# _________________________________________________________________
# quant_dropout (QuantizeWrapp (None, 8, 10, 8)          1
# _________________________________________________________________
# quant_flatten (QuantizeWrapp (None, 640)               1
# _________________________________________________________________
# quant_dense (QuantizeWrapper (None, 4)                 2569
# =================================================================
# Total params: 3,242
# Trainable params: 3,212
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 324/324 [==============================] - 60s 184ms/step - loss: 1.8145 - accuracy: 0.2413 - val_loss: 1.3863 - val_accuracy: 0.2411
#
# Epoch 00001: val_accuracy improved from -inf to 0.24110, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 2/250
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009999940475331661.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.3875 - accuracy: 0.2447 - val_loss: 1.3863 - val_accuracy: 0.2411
#
# Epoch 00002: val_accuracy did not improve from 0.24110
# Epoch 3/250
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000999981994116787.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.3863 - accuracy: 0.2449 - val_loss: 1.3863 - val_accuracy: 0.2411
#
# Epoch 00003: val_accuracy did not improve from 0.24110
# Epoch 4/250
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009999640037705003.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.3904 - accuracy: 0.2448 - val_loss: 1.3863 - val_accuracy: 0.2411
#
# Epoch 00004: val_accuracy did not improve from 0.24110
# Epoch 5/250
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009999399601886404.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.3889 - accuracy: 0.2456 - val_loss: 1.3858 - val_accuracy: 0.2411
#
# Epoch 00005: val_accuracy did not improve from 0.24110
# Epoch 6/250
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.000999909979891992.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.3900 - accuracy: 0.2452 - val_loss: 1.3854 - val_accuracy: 0.2426
#
# Epoch 00006: val_accuracy improved from 0.24110 to 0.24265, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 7/250
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009998739465762805.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4394 - accuracy: 0.2470 - val_loss: 1.4799 - val_accuracy: 0.2442
#
# Epoch 00007: val_accuracy improved from 0.24265 to 0.24420, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 8/250
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009998319767608886.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4435 - accuracy: 0.2465 - val_loss: 1.7355 - val_accuracy: 0.2442
#
# Epoch 00008: val_accuracy did not improve from 0.24420
# Epoch 9/250
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009997839541429343.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.6100 - accuracy: 0.2463 - val_loss: 1.7233 - val_accuracy: 0.2438
#
# Epoch 00009: val_accuracy did not improve from 0.24420
# Epoch 10/250
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009997299952403975.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.9190 - accuracy: 0.2471 - val_loss: 2.2656 - val_accuracy: 0.2442
#
# Epoch 00010: val_accuracy did not improve from 0.24420
# Epoch 11/250
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009996699837517878.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.9878 - accuracy: 0.2476 - val_loss: 2.3004 - val_accuracy: 0.2442
#
# Epoch 00011: val_accuracy did not improve from 0.24420
# Epoch 12/250
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009996040361936833.
# 324/324 [==============================] - 2s 6ms/step - loss: 2.2757 - accuracy: 0.2474 - val_loss: 2.4937 - val_accuracy: 0.2442
#
# Epoch 00012: val_accuracy did not improve from 0.24420
# Epoch 13/250
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009995320362659848.
# 324/324 [==============================] - 2s 6ms/step - loss: 3.0400 - accuracy: 0.2481 - val_loss: 2.3033 - val_accuracy: 0.2496
#
# Epoch 00013: val_accuracy improved from 0.24420 to 0.24961, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 14/250
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009994541004838694.
# 324/324 [==============================] - 2s 6ms/step - loss: 3.5581 - accuracy: 0.2502 - val_loss: 4.8549 - val_accuracy: 0.2454
#
# Epoch 00014: val_accuracy did not improve from 0.24961
# Epoch 15/250
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.000999370112548629.
# 324/324 [==============================] - 2s 6ms/step - loss: 6.2392 - accuracy: 0.2491 - val_loss: 2.9771 - val_accuracy: 0.2508
#
# Epoch 00015: val_accuracy improved from 0.24961 to 0.25077, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 16/250
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009992801889740382.
# 324/324 [==============================] - 2s 6ms/step - loss: 7.4320 - accuracy: 0.2490 - val_loss: 4.2635 - val_accuracy: 0.2504
#
# Epoch 00016: val_accuracy did not improve from 0.25077
# Epoch 17/250
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.000999184213462781.
# 324/324 [==============================] - 2s 6ms/step - loss: 9.5353 - accuracy: 0.2495 - val_loss: 3.2067 - val_accuracy: 0.2496
#
# Epoch 00017: val_accuracy did not improve from 0.25077
# Epoch 18/250
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009990823025272304.
# 324/324 [==============================] - 2s 6ms/step - loss: 12.8070 - accuracy: 0.2486 - val_loss: 22.5114 - val_accuracy: 0.2477
#
# Epoch 00018: val_accuracy did not improve from 0.25077
# Epoch 19/250
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.000998974456274212.
# 324/324 [==============================] - 2s 6ms/step - loss: 21.5154 - accuracy: 0.2491 - val_loss: 19.6837 - val_accuracy: 0.2531
#
# Epoch 00019: val_accuracy improved from 0.25077 to 0.25310, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 20/250
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009988605584084975.
# 324/324 [==============================] - 2s 6ms/step - loss: 29.6245 - accuracy: 0.2498 - val_loss: 35.1897 - val_accuracy: 0.2519
#
# Epoch 00020: val_accuracy did not improve from 0.25310
# Epoch 21/250
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0009987407254403566.
# 324/324 [==============================] - 2s 6ms/step - loss: 37.5653 - accuracy: 0.2548 - val_loss: 46.6475 - val_accuracy: 0.2604
#
# Epoch 00021: val_accuracy improved from 0.25310 to 0.26045, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 22/250
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0009986149574766072.
# 324/324 [==============================] - 2s 6ms/step - loss: 62.9016 - accuracy: 0.2636 - val_loss: 31.1053 - val_accuracy: 0.2531
#
# Epoch 00022: val_accuracy did not improve from 0.26045
# Epoch 23/250
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000998483138224109.
# 324/324 [==============================] - 2s 6ms/step - loss: 78.6521 - accuracy: 0.2970 - val_loss: 127.0027 - val_accuracy: 0.3351
#
# Epoch 00023: val_accuracy improved from 0.26045 to 0.33514, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 24/250
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.000998345384191028.
# 324/324 [==============================] - 2s 6ms/step - loss: 110.2237 - accuracy: 0.3669 - val_loss: 160.8694 - val_accuracy: 0.4137
#
# Epoch 00024: val_accuracy improved from 0.33514 to 0.41370, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 25/250
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0009982016954841755.
# 324/324 [==============================] - 2s 6ms/step - loss: 159.2359 - accuracy: 0.4145 - val_loss: 152.4154 - val_accuracy: 0.4795
#
# Epoch 00025: val_accuracy improved from 0.41370 to 0.47949, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 26/250
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0009980519558124969.
# 324/324 [==============================] - 2s 6ms/step - loss: 154.8974 - accuracy: 0.4603 - val_loss: 72.7320 - val_accuracy: 0.4203
#
# Epoch 00026: val_accuracy did not improve from 0.47949
# Epoch 27/250
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0009978962816820569.
# 324/324 [==============================] - 2s 6ms/step - loss: 149.1622 - accuracy: 0.4686 - val_loss: 104.1423 - val_accuracy: 0.5356
#
# Epoch 00027: val_accuracy improved from 0.47949 to 0.53560, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 28/250
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0009977346731996585.
# 324/324 [==============================] - 2s 6ms/step - loss: 150.3697 - accuracy: 0.4935 - val_loss: 141.8597 - val_accuracy: 0.4199
#
# Epoch 00028: val_accuracy did not improve from 0.53560
# Epoch 29/250
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0009975671304721016.
# 324/324 [==============================] - 2s 6ms/step - loss: 144.1639 - accuracy: 0.5027 - val_loss: 65.7453 - val_accuracy: 0.5399
#
# Epoch 00029: val_accuracy improved from 0.53560 to 0.53986, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 30/250
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0009973935372111155.
# 324/324 [==============================] - 2s 6ms/step - loss: 154.4569 - accuracy: 0.5135 - val_loss: 133.3944 - val_accuracy: 0.4942
#
# Epoch 00030: val_accuracy did not improve from 0.53986
# Epoch 31/250
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0009972140099199606.
# 324/324 [==============================] - 2s 6ms/step - loss: 138.4630 - accuracy: 0.5193 - val_loss: 110.6406 - val_accuracy: 0.5252
#
# Epoch 00031: val_accuracy did not improve from 0.53986
# Epoch 32/250
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00099702854870543.
# 324/324 [==============================] - 2s 6ms/step - loss: 135.7070 - accuracy: 0.5335 - val_loss: 74.9128 - val_accuracy: 0.4880
#
# Epoch 00032: val_accuracy did not improve from 0.53986
# Epoch 33/250
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0009968371536743133.
# 324/324 [==============================] - 2s 6ms/step - loss: 134.5940 - accuracy: 0.5326 - val_loss: 111.2701 - val_accuracy: 0.5851
#
# Epoch 00033: val_accuracy improved from 0.53986 to 0.58514, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 34/250
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0009966398249333986.
# 324/324 [==============================] - 2s 6ms/step - loss: 149.7646 - accuracy: 0.5391 - val_loss: 92.6617 - val_accuracy: 0.6064
#
# Epoch 00034: val_accuracy improved from 0.58514 to 0.60642, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 35/250
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0009964365625894703.
# 324/324 [==============================] - 2s 6ms/step - loss: 130.2488 - accuracy: 0.5456 - val_loss: 154.4159 - val_accuracy: 0.5739
#
# Epoch 00035: val_accuracy did not improve from 0.60642
# Epoch 36/250
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0009962273667493114.
# 324/324 [==============================] - 2s 6ms/step - loss: 139.2710 - accuracy: 0.5503 - val_loss: 70.4026 - val_accuracy: 0.5909
#
# Epoch 00036: val_accuracy did not improve from 0.60642
# Epoch 37/250
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0009960122375197015.
# 324/324 [==============================] - 2s 6ms/step - loss: 127.3421 - accuracy: 0.5561 - val_loss: 84.1416 - val_accuracy: 0.5201
#
# Epoch 00037: val_accuracy did not improve from 0.60642
# Epoch 38/250
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.000995791175007418.
# 324/324 [==============================] - 2s 6ms/step - loss: 123.8812 - accuracy: 0.5603 - val_loss: 100.9395 - val_accuracy: 0.5240
#
# Epoch 00038: val_accuracy did not improve from 0.60642
# Epoch 39/250
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0009955641793192357.
# 324/324 [==============================] - 2s 6ms/step - loss: 114.1175 - accuracy: 0.5705 - val_loss: 60.8542 - val_accuracy: 0.5464
#
# Epoch 00039: val_accuracy did not improve from 0.60642
# Epoch 40/250
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0009953312505619261.
# 324/324 [==============================] - 2s 6ms/step - loss: 121.1394 - accuracy: 0.5654 - val_loss: 69.0310 - val_accuracy: 0.5960
#
# Epoch 00040: val_accuracy did not improve from 0.60642
# Epoch 41/250
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00099509238884226.
# 324/324 [==============================] - 2s 6ms/step - loss: 104.2034 - accuracy: 0.5723 - val_loss: 70.8458 - val_accuracy: 0.5372
#
# Epoch 00041: val_accuracy did not improve from 0.60642
# Epoch 42/250
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0009948477106536942.
# 324/324 [==============================] - 2s 6ms/step - loss: 102.3136 - accuracy: 0.5694 - val_loss: 83.4242 - val_accuracy: 0.6509
#
# Epoch 00042: val_accuracy improved from 0.60642 to 0.65093, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 43/250
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0009945970997149067.
# 324/324 [==============================] - 2s 6ms/step - loss: 100.9549 - accuracy: 0.5810 - val_loss: 59.3668 - val_accuracy: 0.6103
#
# Epoch 00043: val_accuracy did not improve from 0.65093
# Epoch 44/250
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.000994340556132659.
# 324/324 [==============================] - 2s 6ms/step - loss: 88.4704 - accuracy: 0.5825 - val_loss: 59.7707 - val_accuracy: 0.5755
#
# Epoch 00044: val_accuracy did not improve from 0.65093
# Epoch 45/250
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0009940780800137112.
# 324/324 [==============================] - 2s 6ms/step - loss: 79.8288 - accuracy: 0.5796 - val_loss: 54.0930 - val_accuracy: 0.5983
#
# Epoch 00045: val_accuracy did not improve from 0.65093
# Epoch 46/250
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.000993809787848718.
# 324/324 [==============================] - 2s 6ms/step - loss: 75.1731 - accuracy: 0.5843 - val_loss: 54.4615 - val_accuracy: 0.6432
#
# Epoch 00046: val_accuracy did not improve from 0.65093
# Epoch 47/250
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0009935355633591389.
# 324/324 [==============================] - 2s 6ms/step - loss: 66.2765 - accuracy: 0.5878 - val_loss: 61.6289 - val_accuracy: 0.5561
#
# Epoch 00047: val_accuracy did not improve from 0.65093
# Epoch 48/250
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0009932555230342279.
# 324/324 [==============================] - 2s 6ms/step - loss: 59.8712 - accuracy: 0.5902 - val_loss: 50.7615 - val_accuracy: 0.5430
#
# Epoch 00048: val_accuracy did not improve from 0.65093
# Epoch 49/250
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.000992969550596836.
# 324/324 [==============================] - 2s 6ms/step - loss: 51.4138 - accuracy: 0.5906 - val_loss: 40.7221 - val_accuracy: 0.5766
#
# Epoch 00049: val_accuracy did not improve from 0.65093
# Epoch 50/250
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.00099267764615371.
# 324/324 [==============================] - 2s 6ms/step - loss: 43.6750 - accuracy: 0.5917 - val_loss: 31.6039 - val_accuracy: 0.5975
#
# Epoch 00050: val_accuracy did not improve from 0.65093
# Epoch 51/250
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0009923799261920014.
# 324/324 [==============================] - 2s 6ms/step - loss: 35.9982 - accuracy: 0.6016 - val_loss: 25.2968 - val_accuracy: 0.5971
#
# Epoch 00051: val_accuracy did not improve from 0.65093
# Epoch 52/250
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0009920763908163577.
# 324/324 [==============================] - 2s 6ms/step - loss: 29.5996 - accuracy: 0.5964 - val_loss: 22.7328 - val_accuracy: 0.5724
#
# Epoch 00052: val_accuracy did not improve from 0.65093
# Epoch 53/250
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.000991766923752412.
# 324/324 [==============================] - 2s 6ms/step - loss: 23.9499 - accuracy: 0.5945 - val_loss: 17.8915 - val_accuracy: 0.5882
#
# Epoch 00053: val_accuracy did not improve from 0.65093
# Epoch 54/250
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0009914516414852145.
# 324/324 [==============================] - 2s 6ms/step - loss: 20.2922 - accuracy: 0.5897 - val_loss: 13.9452 - val_accuracy: 0.5793
#
# Epoch 00054: val_accuracy did not improve from 0.65093
# Epoch 55/250
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0009911305441194047.
# 324/324 [==============================] - 2s 6ms/step - loss: 16.3206 - accuracy: 0.5945 - val_loss: 11.2330 - val_accuracy: 0.5983
#
# Epoch 00055: val_accuracy did not improve from 0.65093
# Epoch 56/250
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0009908036317596203.
# 324/324 [==============================] - 2s 6ms/step - loss: 14.0543 - accuracy: 0.5918 - val_loss: 9.6350 - val_accuracy: 0.5751
#
# Epoch 00056: val_accuracy did not improve from 0.65093
# Epoch 57/250
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.000990470788134276.
# 324/324 [==============================] - 2s 6ms/step - loss: 10.9192 - accuracy: 0.5844 - val_loss: 7.2458 - val_accuracy: 0.5766
#
# Epoch 00057: val_accuracy did not improve from 0.65093
# Epoch 58/250
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0009901321297256195.
# 324/324 [==============================] - 2s 6ms/step - loss: 9.0818 - accuracy: 0.5869 - val_loss: 6.1855 - val_accuracy: 0.5824
#
# Epoch 00058: val_accuracy did not improve from 0.65093
# Epoch 59/250
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.000989787656638281.
# 324/324 [==============================] - 2s 6ms/step - loss: 7.5095 - accuracy: 0.5791 - val_loss: 4.9666 - val_accuracy: 0.5824
#
# Epoch 00059: val_accuracy did not improve from 0.65093
# Epoch 60/250
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0009894373689768876.
# 324/324 [==============================] - 2s 6ms/step - loss: 5.8813 - accuracy: 0.5689 - val_loss: 4.0314 - val_accuracy: 0.5855
#
# Epoch 00060: val_accuracy did not improve from 0.65093
# Epoch 61/250
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0009890812668460636.
# 324/324 [==============================] - 2s 6ms/step - loss: 4.6302 - accuracy: 0.5807 - val_loss: 3.2833 - val_accuracy: 0.5995
#
# Epoch 00061: val_accuracy did not improve from 0.65093
# Epoch 62/250
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.000988719350350431.
# 324/324 [==============================] - 2s 6ms/step - loss: 3.6306 - accuracy: 0.5811 - val_loss: 2.7737 - val_accuracy: 0.6397
#
# Epoch 00062: val_accuracy did not improve from 0.65093
# Epoch 63/250
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0009883517359666417.
# 324/324 [==============================] - 2s 6ms/step - loss: 2.8743 - accuracy: 0.5941 - val_loss: 2.0272 - val_accuracy: 0.6122
#
# Epoch 00063: val_accuracy did not improve from 0.65093
# Epoch 64/250
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.000987978307425885.
# 324/324 [==============================] - 2s 6ms/step - loss: 2.3774 - accuracy: 0.5953 - val_loss: 1.6077 - val_accuracy: 0.6118
#
# Epoch 00064: val_accuracy did not improve from 0.65093
# Epoch 65/250
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0009875990648327752.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.9673 - accuracy: 0.6100 - val_loss: 1.4000 - val_accuracy: 0.6354
#
# Epoch 00065: val_accuracy did not improve from 0.65093
# Epoch 66/250
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0009872140082919252.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.7035 - accuracy: 0.6129 - val_loss: 1.3074 - val_accuracy: 0.6610
#
# Epoch 00066: val_accuracy improved from 0.65093 to 0.66099, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 67/250
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0009868232542771835.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4338 - accuracy: 0.6190 - val_loss: 1.1553 - val_accuracy: 0.6606
#
# Epoch 00067: val_accuracy did not improve from 0.66099
# Epoch 68/250
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.000986426686522522.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.3070 - accuracy: 0.6166 - val_loss: 1.0342 - val_accuracy: 0.6567
#
# Epoch 00068: val_accuracy did not improve from 0.66099
# Epoch 69/250
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0009860244215003896.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.1397 - accuracy: 0.6166 - val_loss: 0.8982 - val_accuracy: 0.6614
#
# Epoch 00069: val_accuracy improved from 0.66099 to 0.66138, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 70/250
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0009856163429461482.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.0587 - accuracy: 0.6142 - val_loss: 0.8907 - val_accuracy: 0.6622
#
# Epoch 00070: val_accuracy improved from 0.66138 to 0.66215, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 71/250
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0009852025673308454.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.9901 - accuracy: 0.6242 - val_loss: 0.8045 - val_accuracy: 0.6478
#
# Epoch 00071: val_accuracy did not improve from 0.66215
# Epoch 72/250
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.000984783094756985.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.9095 - accuracy: 0.6350 - val_loss: 0.7440 - val_accuracy: 0.6707
#
# Epoch 00072: val_accuracy improved from 0.66215 to 0.67067, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 73/250
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0009843578089620156.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.8807 - accuracy: 0.6292 - val_loss: 0.7477 - val_accuracy: 0.6792
#
# Epoch 00073: val_accuracy improved from 0.67067 to 0.67918, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 74/250
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0009839268264148838.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.8249 - accuracy: 0.6444 - val_loss: 0.6949 - val_accuracy: 0.6842
#
# Epoch 00074: val_accuracy improved from 0.67918 to 0.68421, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 75/250
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0009834901472180852.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.8056 - accuracy: 0.6544 - val_loss: 0.6616 - val_accuracy: 0.7074
#
# Epoch 00075: val_accuracy improved from 0.68421 to 0.70743, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 76/250
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0009830477714741139.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.7672 - accuracy: 0.6709 - val_loss: 0.7063 - val_accuracy: 0.7005
#
# Epoch 00076: val_accuracy did not improve from 0.70743
# Epoch 77/250
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0009825996992854607.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7351 - accuracy: 0.6814 - val_loss: 0.6391 - val_accuracy: 0.7179
#
# Epoch 00077: val_accuracy improved from 0.70743 to 0.71788, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 78/250
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0009821459307546145.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.7382 - accuracy: 0.6827 - val_loss: 0.6951 - val_accuracy: 0.7125
#
# Epoch 00078: val_accuracy did not improve from 0.71788
# Epoch 79/250
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.000981686465984061.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.7995 - accuracy: 0.6717 - val_loss: 0.6007 - val_accuracy: 0.7585
#
# Epoch 00079: val_accuracy improved from 0.71788 to 0.75851, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 80/250
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0009812214214364515.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.7215 - accuracy: 0.7073 - val_loss: 0.5900 - val_accuracy: 0.7810
#
# Epoch 00080: val_accuracy improved from 0.75851 to 0.78096, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 81/250
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0009807506808527046.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.6758 - accuracy: 0.7276 - val_loss: 0.5892 - val_accuracy: 0.7678
#
# Epoch 00081: val_accuracy did not improve from 0.78096
# Epoch 82/250
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.000980274244335299.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.6576 - accuracy: 0.7350 - val_loss: 0.5674 - val_accuracy: 0.7933
#
# Epoch 00082: val_accuracy improved from 0.78096 to 0.79334, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 83/250
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0009797922283447844.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.6587 - accuracy: 0.7400 - val_loss: 0.5604 - val_accuracy: 0.7837
#
# Epoch 00083: val_accuracy did not improve from 0.79334
# Epoch 84/250
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0009793045166241656.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.6229 - accuracy: 0.7566 - val_loss: 0.5371 - val_accuracy: 0.8026
#
# Epoch 00084: val_accuracy improved from 0.79334 to 0.80263, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 85/250
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0009788112256325927.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.6504 - accuracy: 0.7474 - val_loss: 0.5321 - val_accuracy: 0.8050
#
# Epoch 00085: val_accuracy improved from 0.80263 to 0.80495, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 86/250
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0009783122391144607.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6133 - accuracy: 0.7623 - val_loss: 0.5180 - val_accuracy: 0.8139
#
# Epoch 00086: val_accuracy improved from 0.80495 to 0.81385, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 87/250
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0009778076735275187.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.5907 - accuracy: 0.7737 - val_loss: 0.4993 - val_accuracy: 0.8243
#
# Epoch 00087: val_accuracy improved from 0.81385 to 0.82430, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 88/250
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0009772975289721376.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.6284 - accuracy: 0.7590 - val_loss: 0.6027 - val_accuracy: 0.7724
#
# Epoch 00088: val_accuracy did not improve from 0.82430
# Epoch 89/250
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0009767818055486854.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6221 - accuracy: 0.7667 - val_loss: 0.6518 - val_accuracy: 0.7558
#
# Epoch 00089: val_accuracy did not improve from 0.82430
# Epoch 90/250
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.000976260503357529.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.5969 - accuracy: 0.7706 - val_loss: 0.6878 - val_accuracy: 0.7314
#
# Epoch 00090: val_accuracy did not improve from 0.82430
# Epoch 91/250
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0009757336224990315.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.5966 - accuracy: 0.7754 - val_loss: 0.5152 - val_accuracy: 0.8224
#
# Epoch 00091: val_accuracy did not improve from 0.82430
# Epoch 92/250
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0009752011630735541.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.5679 - accuracy: 0.7858 - val_loss: 0.4725 - val_accuracy: 0.8382
#
# Epoch 00092: val_accuracy improved from 0.82430 to 0.83824, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 93/250
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0009746631251814555.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.0279 - accuracy: 0.4846 - val_loss: 1.3863 - val_accuracy: 0.2411
#
# Epoch 00093: val_accuracy did not improve from 0.83824
# Epoch 94/250
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0009741195670982918.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.3941 - accuracy: 0.2450 - val_loss: 1.3863 - val_accuracy: 0.2411
#
# Epoch 00094: val_accuracy did not improve from 0.83824
# Epoch 95/250
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0009735704889233699.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.3940 - accuracy: 0.2459 - val_loss: 1.4812 - val_accuracy: 0.2411
#
# Epoch 00095: val_accuracy did not improve from 0.83824
# Epoch 96/250
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.000973015890755995.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4074 - accuracy: 0.2459 - val_loss: 1.4923 - val_accuracy: 0.2442
#
# Epoch 00096: val_accuracy did not improve from 0.83824
# Epoch 97/250
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0009724557726954699.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.4216 - accuracy: 0.2462 - val_loss: 1.5641 - val_accuracy: 0.2438
#
# Epoch 00097: val_accuracy did not improve from 0.83824
# Epoch 98/250
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0009718901348410946.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4149 - accuracy: 0.2454 - val_loss: 1.3841 - val_accuracy: 0.2426
#
# Epoch 00098: val_accuracy did not improve from 0.83824
# Epoch 99/250
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0009713189772921672.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.4017 - accuracy: 0.2466 - val_loss: 2.1039 - val_accuracy: 0.2411
#
# Epoch 00099: val_accuracy did not improve from 0.83824
# Epoch 100/250
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0009707423583210894.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4958 - accuracy: 0.2464 - val_loss: 1.6009 - val_accuracy: 0.2438
#
# Epoch 00100: val_accuracy did not improve from 0.83824
# Epoch 101/250
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 0.0009701602780261077.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.5361 - accuracy: 0.2471 - val_loss: 2.2603 - val_accuracy: 0.2442
#
# Epoch 00101: val_accuracy did not improve from 0.83824
# Epoch 102/250
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 0.0009695727365054662.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.6627 - accuracy: 0.2471 - val_loss: 1.7636 - val_accuracy: 0.2442
#
# Epoch 00102: val_accuracy did not improve from 0.83824
# Epoch 103/250
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 0.0009689797338574073.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.9927 - accuracy: 0.2482 - val_loss: 2.0315 - val_accuracy: 0.2492
#
# Epoch 00103: val_accuracy did not improve from 0.83824
# Epoch 104/250
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 0.0009683812701801704.
# 324/324 [==============================] - 2s 5ms/step - loss: 2.7906 - accuracy: 0.2490 - val_loss: 2.3352 - val_accuracy: 0.2496
#
# Epoch 00104: val_accuracy did not improve from 0.83824
# Epoch 105/250
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 0.0009677774037433545.
# 324/324 [==============================] - 2s 5ms/step - loss: 3.8093 - accuracy: 0.2488 - val_loss: 2.4599 - val_accuracy: 0.2442
#
# Epoch 00105: val_accuracy did not improve from 0.83824
# Epoch 106/250
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 0.0009671680764731351.
# 324/324 [==============================] - 2s 6ms/step - loss: 5.0861 - accuracy: 0.2489 - val_loss: 3.8185 - val_accuracy: 0.2430
#
# Epoch 00106: val_accuracy did not improve from 0.83824
# Epoch 107/250
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 0.0009665533466384088.
# 324/324 [==============================] - 2s 5ms/step - loss: 7.6099 - accuracy: 0.2490 - val_loss: 3.0095 - val_accuracy: 0.2473
#
# Epoch 00107: val_accuracy did not improve from 0.83824
# Epoch 108/250
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 0.0009659332143363598.
# 324/324 [==============================] - 2s 5ms/step - loss: 5.9068 - accuracy: 0.2493 - val_loss: 3.9704 - val_accuracy: 0.2508
#
# Epoch 00108: val_accuracy did not improve from 0.83824
# Epoch 109/250
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 0.0009653076796641693.
# 324/324 [==============================] - 2s 6ms/step - loss: 9.1231 - accuracy: 0.2499 - val_loss: 5.4160 - val_accuracy: 0.2446
#
# Epoch 00109: val_accuracy did not improve from 0.83824
# Epoch 110/250
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.0009646768008886345.
# 324/324 [==============================] - 2s 5ms/step - loss: 14.7315 - accuracy: 0.2497 - val_loss: 2.9344 - val_accuracy: 0.2515
#
# Epoch 00110: val_accuracy did not improve from 0.83824
# Epoch 111/250
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.0009640405199366162.
# 324/324 [==============================] - 2s 6ms/step - loss: 18.3641 - accuracy: 0.2492 - val_loss: 15.6939 - val_accuracy: 0.2508
#
# Epoch 00111: val_accuracy did not improve from 0.83824
# Epoch 112/250
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.0009633988950742099.
# 324/324 [==============================] - 2s 5ms/step - loss: 28.8312 - accuracy: 0.2492 - val_loss: 9.4729 - val_accuracy: 0.2515
#
# Epoch 00112: val_accuracy did not improve from 0.83824
# Epoch 113/250
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.0009627519263975411.
# 324/324 [==============================] - 2s 5ms/step - loss: 37.3075 - accuracy: 0.2511 - val_loss: 24.3661 - val_accuracy: 0.2515
#
# Epoch 00113: val_accuracy did not improve from 0.83824
# Epoch 114/250
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.0009620996140027332.
# 324/324 [==============================] - 2s 6ms/step - loss: 53.8238 - accuracy: 0.2523 - val_loss: 42.4718 - val_accuracy: 0.2473
#
# Epoch 00114: val_accuracy did not improve from 0.83824
# Epoch 115/250
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.0009614420161537816.
# 324/324 [==============================] - 2s 5ms/step - loss: 72.5623 - accuracy: 0.2528 - val_loss: 39.8715 - val_accuracy: 0.2485
#
# Epoch 00115: val_accuracy did not improve from 0.83824
# Epoch 116/250
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.0009607790747782333.
# 324/324 [==============================] - 2s 6ms/step - loss: 93.6993 - accuracy: 0.2595 - val_loss: 44.0738 - val_accuracy: 0.2604
#
# Epoch 00116: val_accuracy did not improve from 0.83824
# Epoch 117/250
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.0009601108481393819.
# 324/324 [==============================] - 2s 6ms/step - loss: 150.5528 - accuracy: 0.2777 - val_loss: 137.7949 - val_accuracy: 0.2848
#
# Epoch 00117: val_accuracy did not improve from 0.83824
# Epoch 118/250
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.0009594373363322951.
# 324/324 [==============================] - 2s 5ms/step - loss: 231.6606 - accuracy: 0.3279 - val_loss: 77.0460 - val_accuracy: 0.4056
#
# Epoch 00118: val_accuracy did not improve from 0.83824
# Epoch 119/250
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.0009587585394520386.
# 324/324 [==============================] - 2s 5ms/step - loss: 272.5187 - accuracy: 0.3821 - val_loss: 168.4654 - val_accuracy: 0.4269
#
# Epoch 00119: val_accuracy did not improve from 0.83824
# Epoch 120/250
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.0009580744575936758.
# 324/324 [==============================] - 2s 5ms/step - loss: 299.8468 - accuracy: 0.4050 - val_loss: 172.5033 - val_accuracy: 0.4841
#
# Epoch 00120: val_accuracy did not improve from 0.83824
# Epoch 121/250
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.0009573851490180496.
# 324/324 [==============================] - 2s 6ms/step - loss: 329.5266 - accuracy: 0.3928 - val_loss: 254.4320 - val_accuracy: 0.3777
#
# Epoch 00121: val_accuracy did not improve from 0.83824
# Epoch 122/250
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.0009566906138191726.
# 324/324 [==============================] - 2s 6ms/step - loss: 342.3184 - accuracy: 0.3918 - val_loss: 312.8016 - val_accuracy: 0.4369
#
# Epoch 00122: val_accuracy did not improve from 0.83824
# Epoch 123/250
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.0009559908520910553.
# 324/324 [==============================] - 2s 6ms/step - loss: 349.4259 - accuracy: 0.3909 - val_loss: 258.2463 - val_accuracy: 0.4087
#
# Epoch 00123: val_accuracy did not improve from 0.83824
# Epoch 124/250
#
# Epoch 00124: LearningRateScheduler reducing learning rate to 0.0009552858639277056.
# 324/324 [==============================] - 2s 5ms/step - loss: 345.2595 - accuracy: 0.3909 - val_loss: 171.4488 - val_accuracy: 0.4276
#
# Epoch 00124: val_accuracy did not improve from 0.83824
# Epoch 125/250
#
# Epoch 00125: LearningRateScheduler reducing learning rate to 0.0009545756494231294.
# 324/324 [==============================] - 2s 6ms/step - loss: 341.0899 - accuracy: 0.3796 - val_loss: 152.3801 - val_accuracy: 0.4098
#
# Epoch 00125: val_accuracy did not improve from 0.83824
# Epoch 126/250
#
# Epoch 00126: LearningRateScheduler reducing learning rate to 0.0009538602668353685.
# 324/324 [==============================] - 2s 5ms/step - loss: 344.6355 - accuracy: 0.3790 - val_loss: 177.7547 - val_accuracy: 0.4230
#
# Epoch 00126: val_accuracy did not improve from 0.83824
# Epoch 127/250
#
# Epoch 00127: LearningRateScheduler reducing learning rate to 0.0009531397162573779.
# 324/324 [==============================] - 2s 6ms/step - loss: 333.1561 - accuracy: 0.3892 - val_loss: 128.6739 - val_accuracy: 0.4052
#
# Epoch 00127: val_accuracy did not improve from 0.83824
# Epoch 128/250
#
# Epoch 00128: LearningRateScheduler reducing learning rate to 0.0009524139977821108.
# 324/324 [==============================] - 2s 5ms/step - loss: 335.7153 - accuracy: 0.3825 - val_loss: 131.7415 - val_accuracy: 0.4222
#
# Epoch 00128: val_accuracy did not improve from 0.83824
# Epoch 129/250
#
# Epoch 00129: LearningRateScheduler reducing learning rate to 0.0009516831115025175.
# 324/324 [==============================] - 2s 5ms/step - loss: 316.3976 - accuracy: 0.3813 - val_loss: 153.6119 - val_accuracy: 0.4447
#
# Epoch 00129: val_accuracy did not improve from 0.83824
# Epoch 130/250
#
# Epoch 00130: LearningRateScheduler reducing learning rate to 0.0009509470575115472.
# 324/324 [==============================] - 2s 5ms/step - loss: 330.8273 - accuracy: 0.3796 - val_loss: 108.8434 - val_accuracy: 0.3696
#
# Epoch 00130: val_accuracy did not improve from 0.83824
# Epoch 131/250
#
# Epoch 00131: LearningRateScheduler reducing learning rate to 0.0009502058940644402.
# 324/324 [==============================] - 2s 6ms/step - loss: 325.7739 - accuracy: 0.3847 - val_loss: 214.6146 - val_accuracy: 0.5128
#
# Epoch 00131: val_accuracy did not improve from 0.83824
# Epoch 132/250
#
# Epoch 00132: LearningRateScheduler reducing learning rate to 0.0009494596212530944.
# 324/324 [==============================] - 2s 6ms/step - loss: 321.4195 - accuracy: 0.3869 - val_loss: 163.4904 - val_accuracy: 0.4029
#
# Epoch 00132: val_accuracy did not improve from 0.83824
# Epoch 133/250
#
# Epoch 00133: LearningRateScheduler reducing learning rate to 0.0009487082391694056.
# 324/324 [==============================] - 2s 6ms/step - loss: 317.5565 - accuracy: 0.3830 - val_loss: 113.3077 - val_accuracy: 0.3835
#
# Epoch 00133: val_accuracy did not improve from 0.83824
# Epoch 134/250
#
# Epoch 00134: LearningRateScheduler reducing learning rate to 0.0009479517479052673.
# 324/324 [==============================] - 2s 5ms/step - loss: 308.7696 - accuracy: 0.3840 - val_loss: 133.6554 - val_accuracy: 0.3738
#
# Epoch 00134: val_accuracy did not improve from 0.83824
# Epoch 135/250
#
# Epoch 00135: LearningRateScheduler reducing learning rate to 0.0009471902057134707.
# 324/324 [==============================] - 2s 5ms/step - loss: 291.6845 - accuracy: 0.3833 - val_loss: 155.3845 - val_accuracy: 0.3185
#
# Epoch 00135: val_accuracy did not improve from 0.83824
# Epoch 136/250
#
# Epoch 00136: LearningRateScheduler reducing learning rate to 0.0009464236126848586.
# 324/324 [==============================] - 2s 5ms/step - loss: 275.9311 - accuracy: 0.3848 - val_loss: 132.8265 - val_accuracy: 0.3522
#
# Epoch 00136: val_accuracy did not improve from 0.83824
# Epoch 137/250
#
# Epoch 00137: LearningRateScheduler reducing learning rate to 0.0009456519689102723.
# 324/324 [==============================] - 2s 5ms/step - loss: 274.0528 - accuracy: 0.3929 - val_loss: 222.0733 - val_accuracy: 0.3286
#
# Epoch 00137: val_accuracy did not improve from 0.83824
# Epoch 138/250
#
# Epoch 00138: LearningRateScheduler reducing learning rate to 0.0009448752744805501.
# 324/324 [==============================] - 2s 6ms/step - loss: 269.6657 - accuracy: 0.3851 - val_loss: 119.8436 - val_accuracy: 0.3688
#
# Epoch 00138: val_accuracy did not improve from 0.83824
# Epoch 139/250
#
# Epoch 00139: LearningRateScheduler reducing learning rate to 0.0009440935876460338.
# 324/324 [==============================] - 2s 6ms/step - loss: 248.5646 - accuracy: 0.3929 - val_loss: 131.7434 - val_accuracy: 0.3526
#
# Epoch 00139: val_accuracy did not improve from 0.83824
# Epoch 140/250
#
# Epoch 00140: LearningRateScheduler reducing learning rate to 0.0009433068503373555.
# 324/324 [==============================] - 2s 5ms/step - loss: 229.3641 - accuracy: 0.3898 - val_loss: 137.5470 - val_accuracy: 0.3479
#
# Epoch 00140: val_accuracy did not improve from 0.83824
# Epoch 141/250
#
# Epoch 00141: LearningRateScheduler reducing learning rate to 0.0009425151208041551.
# 324/324 [==============================] - 2s 5ms/step - loss: 215.1624 - accuracy: 0.4027 - val_loss: 109.8284 - val_accuracy: 0.3854
#
# Epoch 00141: val_accuracy did not improve from 0.83824
# Epoch 142/250
#
# Epoch 00142: LearningRateScheduler reducing learning rate to 0.0009417183991362164.
# 324/324 [==============================] - 2s 5ms/step - loss: 177.3524 - accuracy: 0.4308 - val_loss: 109.0314 - val_accuracy: 0.4199
#
# Epoch 00142: val_accuracy did not improve from 0.83824
# Epoch 143/250
#
# Epoch 00143: LearningRateScheduler reducing learning rate to 0.0009409167435814314.
# 324/324 [==============================] - 2s 5ms/step - loss: 158.4098 - accuracy: 0.4450 - val_loss: 137.0483 - val_accuracy: 0.4729
#
# Epoch 00143: val_accuracy did not improve from 0.83824
# Epoch 144/250
#
# Epoch 00144: LearningRateScheduler reducing learning rate to 0.0009401101542285345.
# 324/324 [==============================] - 2s 6ms/step - loss: 140.5088 - accuracy: 0.4758 - val_loss: 66.5418 - val_accuracy: 0.4454
#
# Epoch 00144: val_accuracy did not improve from 0.83824
# Epoch 145/250
#
# Epoch 00145: LearningRateScheduler reducing learning rate to 0.0009392985730088441.
# 324/324 [==============================] - 2s 5ms/step - loss: 122.5256 - accuracy: 0.4996 - val_loss: 83.4905 - val_accuracy: 0.5074
#
# Epoch 00145: val_accuracy did not improve from 0.83824
# Epoch 146/250
#
# Epoch 00146: LearningRateScheduler reducing learning rate to 0.0009384821163262644.
# 324/324 [==============================] - 2s 5ms/step - loss: 116.7454 - accuracy: 0.5270 - val_loss: 96.1633 - val_accuracy: 0.5004
#
# Epoch 00146: val_accuracy did not improve from 0.83824
# Epoch 147/250
#
# Epoch 00147: LearningRateScheduler reducing learning rate to 0.000937660726111761.
# 324/324 [==============================] - 2s 5ms/step - loss: 112.7879 - accuracy: 0.5423 - val_loss: 84.6760 - val_accuracy: 0.4985
#
# Epoch 00147: val_accuracy did not improve from 0.83824
# Epoch 148/250
#
# Epoch 00148: LearningRateScheduler reducing learning rate to 0.0009368344606104266.
# 324/324 [==============================] - 2s 6ms/step - loss: 106.9453 - accuracy: 0.5536 - val_loss: 77.2700 - val_accuracy: 0.5526
#
# Epoch 00148: val_accuracy did not improve from 0.83824
# Epoch 149/250
#
# Epoch 00149: LearningRateScheduler reducing learning rate to 0.00093600326175392.
# 324/324 [==============================] - 2s 5ms/step - loss: 106.2357 - accuracy: 0.5634 - val_loss: 95.8432 - val_accuracy: 0.5267
#
# Epoch 00149: val_accuracy did not improve from 0.83824
# Epoch 150/250
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 0.0009351672459423017.
# ...
#
# Epoch 00194: val_accuracy did not improve from 0.83824
# Epoch 195/250
#
# Epoch 00195: LearningRateScheduler reducing learning rate to 0.0008927526242030862.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.0441 - accuracy: 0.6769 - val_loss: 0.8719 - val_accuracy: 0.7337
#
# Epoch 00195: val_accuracy did not improve from 0.83824
# Epoch 196/250
#
# Epoch 00196: LearningRateScheduler reducing learning rate to 0.0008917093069981826.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.0545 - accuracy: 0.6688 - val_loss: 0.7799 - val_accuracy: 0.7330
#
# Epoch 00196: val_accuracy did not improve from 0.83824
# Epoch 197/250
#
# Epoch 00197: LearningRateScheduler reducing learning rate to 0.0008906618744088525.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.0006 - accuracy: 0.6709 - val_loss: 0.7589 - val_accuracy: 0.7330
#
# Epoch 00197: val_accuracy did not improve from 0.83824
# Epoch 198/250
#
# Epoch 00198: LearningRateScheduler reducing learning rate to 0.0008896103265090857.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.9842 - accuracy: 0.6765 - val_loss: 0.7237 - val_accuracy: 0.7349
#
# Epoch 00198: val_accuracy did not improve from 0.83824
# Epoch 199/250
#
# Epoch 00199: LearningRateScheduler reducing learning rate to 0.0008885547215114622.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.9644 - accuracy: 0.6721 - val_loss: 0.7741 - val_accuracy: 0.7310
#
# Epoch 00199: val_accuracy did not improve from 0.83824
# Epoch 200/250
#
# Epoch 00200: LearningRateScheduler reducing learning rate to 0.0008874950594889223.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.9500 - accuracy: 0.6855 - val_loss: 0.7869 - val_accuracy: 0.7392
#
# Epoch 00200: val_accuracy did not improve from 0.83824
# Epoch 201/250
#
# Epoch 00201: LearningRateScheduler reducing learning rate to 0.000886431340514405.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.9272 - accuracy: 0.6833 - val_loss: 0.7152 - val_accuracy: 0.7190
#
# Epoch 00201: val_accuracy did not improve from 0.83824
# Epoch 202/250
#
# Epoch 00202: LearningRateScheduler reducing learning rate to 0.0008853635646608477.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.9222 - accuracy: 0.6806 - val_loss: 0.6953 - val_accuracy: 0.7539
#
# Epoch 00202: val_accuracy did not improve from 0.83824
# Epoch 203/250
#
# Epoch 00203: LearningRateScheduler reducing learning rate to 0.0008842917901383843.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.9025 - accuracy: 0.6757 - val_loss: 0.7109 - val_accuracy: 0.7376
#
# Epoch 00203: val_accuracy did not improve from 0.83824
# Epoch 204/250
#
# Epoch 00204: LearningRateScheduler reducing learning rate to 0.0008832160170189034.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8650 - accuracy: 0.6914 - val_loss: 0.6939 - val_accuracy: 0.7461
#
# Epoch 00204: val_accuracy did not improve from 0.83824
# Epoch 205/250
#
# Epoch 00205: LearningRateScheduler reducing learning rate to 0.0008821363035107935.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8480 - accuracy: 0.6879 - val_loss: 0.6684 - val_accuracy: 0.7380
#
# Epoch 00205: val_accuracy did not improve from 0.83824
# Epoch 206/250
#
# Epoch 00206: LearningRateScheduler reducing learning rate to 0.0008810525915487408.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8623 - accuracy: 0.6905 - val_loss: 0.6848 - val_accuracy: 0.7326
#
# Epoch 00206: val_accuracy did not improve from 0.83824
# Epoch 207/250
#
# Epoch 00207: LearningRateScheduler reducing learning rate to 0.000879964939340434.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8339 - accuracy: 0.6926 - val_loss: 0.6531 - val_accuracy: 0.7473
#
# Epoch 00207: val_accuracy did not improve from 0.83824
# Epoch 208/250
#
# Epoch 00208: LearningRateScheduler reducing learning rate to 0.0008788734050921663.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8544 - accuracy: 0.6802 - val_loss: 0.6524 - val_accuracy: 0.7515
#
# Epoch 00208: val_accuracy did not improve from 0.83824
# Epoch 209/250
#
# Epoch 00209: LearningRateScheduler reducing learning rate to 0.0008777779307386187.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8058 - accuracy: 0.7003 - val_loss: 0.6657 - val_accuracy: 0.7272
#
# Epoch 00209: val_accuracy did not improve from 0.83824
# Epoch 210/250
#
# Epoch 00210: LearningRateScheduler reducing learning rate to 0.0008766785744853843.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8126 - accuracy: 0.6907 - val_loss: 0.6577 - val_accuracy: 0.7492
#
# Epoch 00210: val_accuracy did not improve from 0.83824
# Epoch 211/250
#
# Epoch 00211: LearningRateScheduler reducing learning rate to 0.0008755753364022494.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7847 - accuracy: 0.7009 - val_loss: 0.6562 - val_accuracy: 0.7496
#
# Epoch 00211: val_accuracy did not improve from 0.83824
# Epoch 212/250
#
# Epoch 00212: LearningRateScheduler reducing learning rate to 0.000874468274693062.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7806 - accuracy: 0.6987 - val_loss: 0.6384 - val_accuracy: 0.7485
#
# Epoch 00212: val_accuracy did not improve from 0.83824
# Epoch 213/250
#
# Epoch 00213: LearningRateScheduler reducing learning rate to 0.0008733573894265596.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7756 - accuracy: 0.7045 - val_loss: 0.6478 - val_accuracy: 0.7775
#
# Epoch 00213: val_accuracy did not improve from 0.83824
# Epoch 214/250
#
# Epoch 00214: LearningRateScheduler reducing learning rate to 0.0008722426806714786.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7789 - accuracy: 0.6966 - val_loss: 0.6417 - val_accuracy: 0.7481
#
# Epoch 00214: val_accuracy did not improve from 0.83824
# Epoch 215/250
#
# Epoch 00215: LearningRateScheduler reducing learning rate to 0.0008711241484965532.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7468 - accuracy: 0.7149 - val_loss: 0.5981 - val_accuracy: 0.7724
#
# Epoch 00215: val_accuracy did not improve from 0.83824
# Epoch 216/250
#
# Epoch 00216: LearningRateScheduler reducing learning rate to 0.0008700018511031865.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7733 - accuracy: 0.7038 - val_loss: 0.5807 - val_accuracy: 0.7790
#
# Epoch 00216: val_accuracy did not improve from 0.83824
# Epoch 217/250
#
# Epoch 00217: LearningRateScheduler reducing learning rate to 0.0008688757885590646.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7735 - accuracy: 0.7002 - val_loss: 0.6612 - val_accuracy: 0.7310
#
# Epoch 00217: val_accuracy did not improve from 0.83824
# Epoch 218/250
#
# Epoch 00218: LearningRateScheduler reducing learning rate to 0.0008677459609318719.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7170 - accuracy: 0.7187 - val_loss: 0.5930 - val_accuracy: 0.7721
#
# Epoch 00218: val_accuracy did not improve from 0.83824
# Epoch 219/250
#
# Epoch 00219: LearningRateScheduler reducing learning rate to 0.000866612426420916.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7537 - accuracy: 0.7133 - val_loss: 0.5957 - val_accuracy: 0.7763
#
# Epoch 00219: val_accuracy did not improve from 0.83824
# Epoch 220/250
#
# Epoch 00220: LearningRateScheduler reducing learning rate to 0.0008654751850928338.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.7040 - accuracy: 0.7259 - val_loss: 0.5713 - val_accuracy: 0.7829
#
# Epoch 00220: val_accuracy did not improve from 0.83824
# Epoch 221/250
#
# Epoch 00221: LearningRateScheduler reducing learning rate to 0.0008643342370142597.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7095 - accuracy: 0.7169 - val_loss: 0.6004 - val_accuracy: 0.7891
#
# Epoch 00221: val_accuracy did not improve from 0.83824
# Epoch 222/250
#
# Epoch 00222: LearningRateScheduler reducing learning rate to 0.0008631896403824066.
#  - ETA: 1s - loss: 0.7709 - accuracy: 0.7055
#
# Epoch 00222: val_accuracy did not improve from 0.83824
# Epoch 223/250
#
# Epoch 00223: LearningRateScheduler reducing learning rate to 0.000862041395262861.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6844 - accuracy: 0.7271 - val_loss: 0.5680 - val_accuracy: 0.7860
#
# Epoch 00223: val_accuracy did not improve from 0.83824
# Epoch 224/250
#
# Epoch 00224: LearningRateScheduler reducing learning rate to 0.0008608895017212082.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6770 - accuracy: 0.7374 - val_loss: 0.5952 - val_accuracy: 0.7790
#
# Epoch 00224: val_accuracy did not improve from 0.83824
# Epoch 225/250
#
# Epoch 00225: LearningRateScheduler reducing learning rate to 0.0008597340179525664.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6949 - accuracy: 0.7273 - val_loss: 0.5599 - val_accuracy: 0.7837
#
# Epoch 00225: val_accuracy did not improve from 0.83824
# Epoch 226/250
#
# Epoch 00226: LearningRateScheduler reducing learning rate to 0.0008585749440214724.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6941 - accuracy: 0.7279 - val_loss: 0.5919 - val_accuracy: 0.7562
#
# Epoch 00226: val_accuracy did not improve from 0.83824
# Epoch 227/250
#
# Epoch 00227: LearningRateScheduler reducing learning rate to 0.0008574122799924618.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6953 - accuracy: 0.7279 - val_loss: 0.5554 - val_accuracy: 0.7806
#
# Epoch 00227: val_accuracy did not improve from 0.83824
# Epoch 228/250
#
# Epoch 00228: LearningRateScheduler reducing learning rate to 0.0008562460840585581.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6732 - accuracy: 0.7364 - val_loss: 0.5458 - val_accuracy: 0.7875
#
# Epoch 00228: val_accuracy did not improve from 0.83824
# Epoch 229/250
#
# Epoch 00229: LearningRateScheduler reducing learning rate to 0.0008550763562832491.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6693 - accuracy: 0.7380 - val_loss: 0.5716 - val_accuracy: 0.7794
#
# Epoch 00229: val_accuracy did not improve from 0.83824
# Epoch 230/250
#
# Epoch 00230: LearningRateScheduler reducing learning rate to 0.0008539030967300205.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6677 - accuracy: 0.7442 - val_loss: 0.5549 - val_accuracy: 0.7968
#
# Epoch 00230: val_accuracy did not improve from 0.83824
# Epoch 231/250
#
# Epoch 00231: LearningRateScheduler reducing learning rate to 0.0008527263054623568.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.6920 - accuracy: 0.7366 - val_loss: 0.5362 - val_accuracy: 0.8019
#
# Epoch 00231: val_accuracy did not improve from 0.83824
# Epoch 232/250
#
# Epoch 00232: LearningRateScheduler reducing learning rate to 0.0008515460406708374.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6596 - accuracy: 0.7413 - val_loss: 0.5385 - val_accuracy: 0.7914
#
# Epoch 00232: val_accuracy did not improve from 0.83824
# Epoch 233/250
#
# Epoch 00233: LearningRateScheduler reducing learning rate to 0.0008503623605446475.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7630 - accuracy: 0.6896 - val_loss: 0.9919 - val_accuracy: 0.5534
#
# Epoch 00233: val_accuracy did not improve from 0.83824
# Epoch 234/250
#
# Epoch 00234: LearningRateScheduler reducing learning rate to 0.0008491752070187772.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6900 - accuracy: 0.7363 - val_loss: 0.5572 - val_accuracy: 0.7856
#
# Epoch 00234: val_accuracy did not improve from 0.83824
# Epoch 235/250
#
# Epoch 00235: LearningRateScheduler reducing learning rate to 0.0008479846382817119.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7031 - accuracy: 0.7198 - val_loss: 0.6093 - val_accuracy: 0.7740
#
# Epoch 00235: val_accuracy did not improve from 0.83824
# Epoch 236/250
#
# Epoch 00236: LearningRateScheduler reducing learning rate to 0.0008467906543948386.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6587 - accuracy: 0.7498 - val_loss: 0.5768 - val_accuracy: 0.7813
#
# Epoch 00236: val_accuracy did not improve from 0.83824
# Epoch 237/250
#
# Epoch 00237: LearningRateScheduler reducing learning rate to 0.0008455933135448985.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6366 - accuracy: 0.7549 - val_loss: 0.5340 - val_accuracy: 0.7949
#
# Epoch 00237: val_accuracy did not improve from 0.83824
# Epoch 238/250
#
# Epoch 00238: LearningRateScheduler reducing learning rate to 0.0008443926157922316.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6514 - accuracy: 0.7480 - val_loss: 0.5513 - val_accuracy: 0.7860
#
# Epoch 00238: val_accuracy did not improve from 0.83824
# Epoch 239/250
#
# Epoch 00239: LearningRateScheduler reducing learning rate to 0.0008431885611971757.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6405 - accuracy: 0.7485 - val_loss: 0.5487 - val_accuracy: 0.7953
#
# Epoch 00239: val_accuracy did not improve from 0.83824
# Epoch 240/250
#
# Epoch 00240: LearningRateScheduler reducing learning rate to 0.0008419811498200673.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6423 - accuracy: 0.7561 - val_loss: 0.5337 - val_accuracy: 0.8022
#
# Epoch 00240: val_accuracy did not improve from 0.83824
# Epoch 241/250
#
# Epoch 00241: LearningRateScheduler reducing learning rate to 0.000840770439845204.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6382 - accuracy: 0.7550 - val_loss: 0.5608 - val_accuracy: 0.7872
#
# Epoch 00241: val_accuracy did not improve from 0.83824
# Epoch 242/250
#
# Epoch 00242: LearningRateScheduler reducing learning rate to 0.000839556431331875.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.8401 - accuracy: 0.6187 - val_loss: 1.3863 - val_accuracy: 0.2411
#
# Epoch 00242: val_accuracy did not improve from 0.83824
# Epoch 243/250
#
# Epoch 00243: LearningRateScheduler reducing learning rate to 0.000838339182462634.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4153 - accuracy: 0.2456 - val_loss: 1.5798 - val_accuracy: 0.2500
#
# Epoch 00243: val_accuracy did not improve from 0.83824
# Epoch 244/250
#
# Epoch 00244: LearningRateScheduler reducing learning rate to 0.0008371186351728045.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.4888 - accuracy: 0.2478 - val_loss: 1.5647 - val_accuracy: 0.2500
#
# Epoch 00244: val_accuracy did not improve from 0.83824
# Epoch 245/250
#
# Epoch 00245: LearningRateScheduler reducing learning rate to 0.0008358949057668103.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.6957 - accuracy: 0.2466 - val_loss: 1.3829 - val_accuracy: 0.2438
#
# Epoch 00245: val_accuracy did not improve from 0.83824
# Epoch 246/250
#
# Epoch 00246: LearningRateScheduler reducing learning rate to 0.0008346679361796239.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.5216 - accuracy: 0.2485 - val_loss: 1.5586 - val_accuracy: 0.2477
#
# Epoch 00246: val_accuracy did not improve from 0.83824
# Epoch 247/250
#
# Epoch 00247: LearningRateScheduler reducing learning rate to 0.0008334377845913562.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.6137 - accuracy: 0.2484 - val_loss: 1.6568 - val_accuracy: 0.2426
#
# Epoch 00247: val_accuracy did not improve from 0.83824
# Epoch 248/250
#
# Epoch 00248: LearningRateScheduler reducing learning rate to 0.0008322044510591981.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.7673 - accuracy: 0.2497 - val_loss: 1.5588 - val_accuracy: 0.2430
#
# Epoch 00248: val_accuracy did not improve from 0.83824
# Epoch 249/250
#
# Epoch 00249: LearningRateScheduler reducing learning rate to 0.0008309679937615163.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.9189 - accuracy: 0.2501 - val_loss: 1.4319 - val_accuracy: 0.2492
#
# Epoch 00249: val_accuracy did not improve from 0.83824
# Epoch 250/250
#
# Epoch 00250: LearningRateScheduler reducing learning rate to 0.0008297283546336258.
# 324/324 [==============================] - 2s 6ms/step - loss: 1.8871 - accuracy: 0.2503 - val_loss: 2.5268 - val_accuracy: 0.2504
#
# Epoch 00250: val_accuracy did not improve from 0.83824

# %% [markdown]
# ## Visualización de historial de entrenamiento
#
# Se visualiza accuracy y loss de training y validation.

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title(f"Training and Validation Accuracy\nfor {model_name}")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.title(f"Training and Validation Loss\nfor {model_name}")

plt.savefig(f"{log_dir}/{model_name}_training_data.jpg")

plt.show()

# %% [markdown]
# ## Guardar modelo
# Guardamos el modelo entrenado para poder reutilizarlo en el futuro.

# %%
tf.keras.models.save_model(model, model_dir)
# Out:
# WARNING:absl:Found untraced functions such as conv2d_layer_call_and_return_conditional_losses, conv2d_layer_call_fn, dropout_layer_call_and_return_conditional_losses, dropout_layer_call_fn, flatten_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
