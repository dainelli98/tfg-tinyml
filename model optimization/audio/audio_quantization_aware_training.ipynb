# %% [markdown]
# # Audio quantization aware training
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from joblib import dump
import matplotlib.pyplot as plt

from audio_model_optimization import *
from audio_model_training import get_audio_datasets, CLASS_NAMES, NCLASSES, get_audio_model

# %% [markdown]
# ## Parámetros
# Se establecen los parámetros para la optimización.

# %%
project_dir = "/home/daniel/PycharmProjects/tfg-tinyml"
saved_models_dir = f"{project_dir}/saved models/audio"
original_model_name = "ExtAudioDataModel"
checkpoint_dir = f"{saved_models_dir}/tensorflow/checkpoints"
label_index_dir = f"{saved_models_dir}/label index mappings"

model_name = f"{original_model_name}QAT"
checkpoint_path = f"{checkpoint_dir}/{model_name}.hdf5"

data_dir = f"{project_dir}/samples/external/audio/train"
log_dir = f"{saved_models_dir}/summaries/{model_name}"
model_dir = f"{saved_models_dir}/tensorflow/{model_name}"

validation_percentage = 20.
initial_learning_rate = 0.001
decay = (initial_learning_rate / QUANT_EPOCHS) * 1.5

# %% [markdown]
# ## Carga de datos
# Se cargan los mismos datasets de entrenamiento y validación que se han usado en el entrenamiento.

# %%
train_dataset, validation_dataset = get_audio_datasets(data_dir, validation_percentage)

class_list_text = "Classes:"
for index, name in enumerate(CLASS_NAMES):
    class_list_text += f"\n\t{index}: {name}"

print(class_list_text)
with open(f"{label_index_dir}/{model_name}.txt", "wt") as text_file:
    text_file.write(class_list_text)

dump(CLASS_NAMES, f"{label_index_dir}/{model_name}.joblib")

train_dataset = normalize_dataset(train_dataset)
validation_dataset = normalize_dataset(validation_dataset)
# Out:
# Se usarán 12924 muestras:
# 	- Train: 10340
# 	- Validation: 2584
# WARNING:tensorflow:From /home/daniel/.local/lib/python3.8/site-packages/tensorflow/python/ops/parallel_for/pfor.py:2380: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# Classes:
# 	0: no
# 	1: silence
# 	2: unknown
# 	3: yes

# %% [markdown]
# ## Quantization aware training
# Se reentrena el modelo usando quantization aware training.

# %%
model = get_audio_model((129, 124, 1), model_name, train_dataset, normalize=False)

model = tfmot.quantization.keras.quantize_model(model)

def lr_time_based_decay(epoch: int, lr: float) -> float:
    """
    Callback function que reduce el learning rate conforme avanza el entrenamiento.
    Args:
        epoch:  int que representa el epoch del entrenamiento que se va a realizar a continuación.
        lr:     float con el learning rate del último epoch.

    Returns:
        float con el nuevo learning rate
    """
    return lr * 1 / (1 + decay * epoch)

model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, monitor='val_accuracy',
                                            mode='max', save_best_only=True, verbose=1)

early_stopping_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=QUANT_PATIENCE)

callbacks = [LearningRateScheduler(lr_time_based_decay, verbose=1), model_checkpoint_callback, early_stopping_callback]

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=QUANT_EPOCHS,
    callbacks=callbacks
)

model.load_weights(checkpoint_path)
# Out:
# Model: "ExtAudioDataModelQAT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quantize_layer (QuantizeLaye (None, 129, 124, 1)       3
# _________________________________________________________________
# quant_conv2d (QuantizeWrappe (None, 61, 58, 8)         667
# _________________________________________________________________
# quant_max_pooling2d (Quantiz (None, 30, 29, 8)         1
# _________________________________________________________________
# quant_dropout (QuantizeWrapp (None, 30, 29, 8)         1
# _________________________________________________________________
# quant_flatten (QuantizeWrapp (None, 6960)              1
# _________________________________________________________________
# quant_dense (QuantizeWrapper (None, 4)                 27849
# =================================================================
# Total params: 28,522
# Trainable params: 28,492
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 324/324 [==============================] - 9s 25ms/step - loss: 0.7566 - accuracy: 0.6992 - val_loss: 0.5662 - val_accuracy: 0.7693
#
# Epoch 00001: val_accuracy improved from -inf to 0.76935, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 2/250
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009999940475331661.
#  - ETA: 4s - loss: 0.4861 - accuracy: 0.8142
#
# Epoch 00002: val_accuracy improved from 0.76935 to 0.86997, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 3/250
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000999981994116787.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.3235 - accuracy: 0.8797 - val_loss: 0.3284 - val_accuracy: 0.8835
#
# Epoch 00003: val_accuracy improved from 0.86997 to 0.88351, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 4/250
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009999640037705003.
# 324/324 [==============================] - 8s 26ms/step - loss: 0.2682 - accuracy: 0.9014 - val_loss: 0.3037 - val_accuracy: 0.8959
#
# Epoch 00004: val_accuracy improved from 0.88351 to 0.89590, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 5/250
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009999399601886404.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.2346 - accuracy: 0.9126 - val_loss: 0.3205 - val_accuracy: 0.8967
#
# Epoch 00005: val_accuracy improved from 0.89590 to 0.89667, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 6/250
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.000999909979891992.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.2164 - accuracy: 0.9195 - val_loss: 0.3219 - val_accuracy: 0.8963
#
# Epoch 00006: val_accuracy did not improve from 0.89667
# Epoch 7/250
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009998739465762805.
# 324/324 [==============================] - 8s 24ms/step - loss: 0.2030 - accuracy: 0.9242 - val_loss: 0.3103 - val_accuracy: 0.9013
#
# Epoch 00007: val_accuracy improved from 0.89667 to 0.90132, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 8/250
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009998319767608886.
# 324/324 [==============================] - 8s 24ms/step - loss: 0.1986 - accuracy: 0.9269 - val_loss: 0.3025 - val_accuracy: 0.8990
#
# Epoch 00008: val_accuracy did not improve from 0.90132
# Epoch 9/250
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009997839541429343.
# 324/324 [==============================] - 8s 26ms/step - loss: 0.1848 - accuracy: 0.9307 - val_loss: 0.3067 - val_accuracy: 0.9029
#
# Epoch 00009: val_accuracy improved from 0.90132 to 0.90286, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 10/250
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009997299952403975.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.1709 - accuracy: 0.9371 - val_loss: 0.3240 - val_accuracy: 0.9021
#
# Epoch 00010: val_accuracy did not improve from 0.90286
# Epoch 11/250
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009996699837517878.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.1673 - accuracy: 0.9379 - val_loss: 0.3230 - val_accuracy: 0.9017
#
# Epoch 00011: val_accuracy did not improve from 0.90286
# Epoch 12/250
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009996040361936833.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.1613 - accuracy: 0.9377 - val_loss: 0.3275 - val_accuracy: 0.9098
#
# Epoch 00012: val_accuracy improved from 0.90286 to 0.90983, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 13/250
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009995320362659848.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.1546 - accuracy: 0.9415 - val_loss: 0.3410 - val_accuracy: 0.9060
#
# Epoch 00013: val_accuracy did not improve from 0.90983
# Epoch 14/250
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009994541004838694.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.1521 - accuracy: 0.9422 - val_loss: 0.3556 - val_accuracy: 0.8994
#
# Epoch 00014: val_accuracy did not improve from 0.90983
# Epoch 15/250
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.000999370112548629.
# 324/324 [==============================] - 8s 25ms/step - loss: 0.1436 - accuracy: 0.9455 - val_loss: 0.3648 - val_accuracy: 0.9052
#
# Epoch 00015: val_accuracy did not improve from 0.90983
# Epoch 16/250
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009992801889740382.
# 324/324 [==============================] - 8s 26ms/step - loss: 0.1458 - accuracy: 0.9458 - val_loss: 0.3706 - val_accuracy: 0.9013
#
# Epoch 00016: val_accuracy did not improve from 0.90983
# Epoch 17/250
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.000999184213462781.
# 324/324 [==============================] - 9s 27ms/step - loss: 0.1417 - accuracy: 0.9455 - val_loss: 0.3547 - val_accuracy: 0.9083
#
# Epoch 00017: val_accuracy did not improve from 0.90983
# Epoch 18/250
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009990823025272304.
# 324/324 [==============================] - 9s 26ms/step - loss: 0.1325 - accuracy: 0.9477 - val_loss: 0.3727 - val_accuracy: 0.9025
#
# Epoch 00018: val_accuracy did not improve from 0.90983
# Epoch 19/250
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.000998974456274212.
# 324/324 [==============================] - 8s 26ms/step - loss: 0.1442 - accuracy: 0.9442 - val_loss: 0.3749 - val_accuracy: 0.9048
#
# Epoch 00019: val_accuracy did not improve from 0.90983
# Epoch 20/250
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009988605584084975.
# 324/324 [==============================] - 8s 26ms/step - loss: 0.1254 - accuracy: 0.9496 - val_loss: 0.3575 - val_accuracy: 0.9048
#
# Epoch 00020: val_accuracy did not improve from 0.90983
# Epoch 21/250
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0009987407254403566.
# 324/324 [==============================] - 9s 26ms/step - loss: 0.1236 - accuracy: 0.9509 - val_loss: 0.3665 - val_accuracy: 0.9137
#
# Epoch 00021: val_accuracy improved from 0.90983 to 0.91370, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 22/250
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0009986149574766072.
# 324/324 [==============================] - 8s 26ms/step - loss: 0.1227 - accuracy: 0.9528 - val_loss: 0.3733 - val_accuracy: 0.9048
#
# Epoch 00022: val_accuracy did not improve from 0.91370
# Epoch 23/250
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000998483138224109.
# 324/324 [==============================] - 9s 27ms/step - loss: 0.1237 - accuracy: 0.9524 - val_loss: 0.3775 - val_accuracy: 0.9114
#
# Epoch 00023: val_accuracy did not improve from 0.91370
# Epoch 24/250
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.000998345384191028.
# 324/324 [==============================] - 9s 27ms/step - loss: 0.1154 - accuracy: 0.9548 - val_loss: 0.3768 - val_accuracy: 0.9021
#
# Epoch 00024: val_accuracy did not improve from 0.91370
# Epoch 25/250
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0009982016954841755.
# 324/324 [==============================] - 9s 28ms/step - loss: 0.1059 - accuracy: 0.9569 - val_loss: 0.3775 - val_accuracy: 0.9122
#
# Epoch 00025: val_accuracy did not improve from 0.91370
# Epoch 26/250
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0009980519558124969.
# 324/324 [==============================] - 9s 26ms/step - loss: 0.1261 - accuracy: 0.9526 - val_loss: 0.3395 - val_accuracy: 0.9203
#
# Epoch 00026: val_accuracy improved from 0.91370 to 0.92028, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 27/250
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0009978962816820569.
# 324/324 [==============================] - 9s 27ms/step - loss: 0.1070 - accuracy: 0.9579 - val_loss: 0.3723 - val_accuracy: 0.9102
#
# Epoch 00027: val_accuracy did not improve from 0.92028
# Epoch 28/250
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0009977346731996585.
# 324/324 [==============================] - 9s 26ms/step - loss: 0.1077 - accuracy: 0.9565 - val_loss: 0.3976 - val_accuracy: 0.9079
#
# Epoch 00028: val_accuracy did not improve from 0.92028
# Epoch 00028: early stopping

# %% [markdown]
# ## Visualización de historial de entrenamiento
#
# Se visualiza accuracy y loss de training y validation.

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title(f"Training and Validation Accuracy\nfor {model_name}")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.title(f"Training and Validation Loss\nfor {model_name}")

plt.savefig(f"{log_dir}/{model_name}_training_data.jpg")

plt.show()

# %% [markdown]
# ## Guardar modelo
# Guardamos el modelo entrenado para poder reutilizarlo en el futuro.

# %%
tf.keras.models.save_model(model, model_dir)
# Out:
# WARNING:absl:Found untraced functions such as conv2d_layer_call_fn, conv2d_layer_call_and_return_conditional_losses, dropout_layer_call_fn, dropout_layer_call_and_return_conditional_losses, flatten_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
