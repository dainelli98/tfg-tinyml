# %% [markdown]
# # Audio quantization aware training
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from joblib import dump
import matplotlib.pyplot as plt

from audio_model_optimization import *
from audio_model_training import get_audio_datasets, CLASS_NAMES, NCLASSES, get_audio_model

# %% [markdown]
# ## Parámetros
# Se establecen los parámetros para la optimización.

# %%
project_dir = "/home/daniel/PycharmProjects/tfg-tinyml"
saved_models_dir = f"{project_dir}/saved models/audio"
original_model_name = "ExtAudioDataModel"
checkpoint_dir = f"{saved_models_dir}/tensorflow/checkpoints"
label_index_dir = f"{saved_models_dir}/label index mappings"

model_name = f"{original_model_name}QAT"
checkpoint_path = f"{checkpoint_dir}/{model_name}.hdf5"

data_dir = f"{project_dir}/samples/external/audio/train"
log_dir = f"{saved_models_dir}/summaries/{model_name}"
model_dir = f"{saved_models_dir}/tensorflow/{model_name}"

validation_percentage = 20.
initial_learning_rate = 0.001
decay = (initial_learning_rate / QUANT_EPOCHS) * 1.5

# %% [markdown]
# ## Carga de datos
# Se cargan los mismos datasets de entrenamiento y validación que se han usado en el entrenamiento.

# %%
train_dataset, validation_dataset = get_audio_datasets(data_dir, validation_percentage)

class_list_text = "Classes:"
for index, name in enumerate(CLASS_NAMES):
    class_list_text += f"\n\t{index}: {name}"

print(class_list_text)
with open(f"{label_index_dir}/{model_name}.txt", "wt") as text_file:
    text_file.write(class_list_text)

dump(CLASS_NAMES, f"{label_index_dir}/{model_name}.joblib")

# Estas operaciones no se pueden aplicar a los datos en el microcontrolador.
# train_dataset = normalize_dataset(train_dataset)
# validation_dataset = normalize_dataset(validation_dataset)
# Out:
# Se usarán 12924 muestras:
# 	- Train: 10340
# 	- Validation: 2584
# WARNING:tensorflow:From /home/daniel/.local/lib/python3.8/site-packages/tensorflow/python/ops/parallel_for/pfor.py:2380: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# Classes:
# 	0: no
# 	1: silence
# 	2: unknown
# 	3: yes
# ['/home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/label index mappings/ExtAudioDataModelQAT.joblib']

# %% [markdown]
# ## Quantization aware training
# Como no sirve el modelo entrenado anteriormente debido a que para usar quantization-aware training hay que eliminar una
# capa primero se entrena si cuantizar un nuevo modelo y luego se reentrena usando quantization-aware training.

# %%
def lr_time_based_decay(epoch: int, lr: float) -> float:
    """
    Callback function que reduce el learning rate conforme avanza el entrenamiento.
    Args:
        epoch:  int que representa el epoch del entrenamiento que se va a realizar a continuación.
        lr:     float con el learning rate del último epoch.

    Returns:
        float con el nuevo learning rate
    """
    return lr * 1 / (1 + decay * epoch)

model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, monitor='val_accuracy',
                                            mode='max', save_best_only=True, verbose=1)

early_stopping_callback = EarlyStopping(monitor='val_loss', verbose=1, patience=QUANT_PATIENCE)

callbacks = [LearningRateScheduler(lr_time_based_decay, verbose=1), model_checkpoint_callback, early_stopping_callback]

model = get_audio_model((40, 49, 1), model_name, train_dataset, normalize=False)

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history1 = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=QUANT_EPOCHS,
    callbacks=callbacks
)

model.load_weights(checkpoint_path)

model = tfmot.quantization.keras.quantize_model(model)

model.summary()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history2 = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=QUANT_EPOCHS,
    callbacks=callbacks
)

model.load_weights(checkpoint_path)
# Out:
# Model: "ExtAudioDataModelQAT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 17, 20, 8)         648
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 8, 10, 8)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 10, 8)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2564
# =================================================================
# Total params: 3,212
# Trainable params: 3,212
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 324/324 [==============================] - 58s 179ms/step - loss: 1.7056 - accuracy: 0.2516 - val_loss: 1.3865 - val_accuracy: 0.2411
#
# Epoch 00001: val_accuracy improved from -inf to 0.24110, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 2/250
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009999940475331661.
# 324/324 [==============================] - 2s 5ms/step - loss: 1.1339 - accuracy: 0.4614 - val_loss: 0.7182 - val_accuracy: 0.7279
#
# Epoch 00002: val_accuracy improved from 0.24110 to 0.72794, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 3/250
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000999981994116787.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.7028 - accuracy: 0.7309 - val_loss: 0.5465 - val_accuracy: 0.7899
#
# Epoch 00003: val_accuracy improved from 0.72794 to 0.78986, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 4/250
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009999640037705003.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.6220 - accuracy: 0.7598 - val_loss: 0.5092 - val_accuracy: 0.8142
#
# Epoch 00004: val_accuracy improved from 0.78986 to 0.81424, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 5/250
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009999399601886404.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.5502 - accuracy: 0.7924 - val_loss: 0.4792 - val_accuracy: 0.8262
#
# Epoch 00005: val_accuracy improved from 0.81424 to 0.82624, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 6/250
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.000999909979891992.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4950 - accuracy: 0.8165 - val_loss: 0.5265 - val_accuracy: 0.8158
#
# Epoch 00006: val_accuracy did not improve from 0.82624
# Epoch 7/250
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009998739465762805.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4551 - accuracy: 0.8305 - val_loss: 0.4196 - val_accuracy: 0.8417
#
# Epoch 00007: val_accuracy improved from 0.82624 to 0.84172, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 8/250
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009998319767608886.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4341 - accuracy: 0.8372 - val_loss: 0.6865 - val_accuracy: 0.7519
#
# Epoch 00008: val_accuracy did not improve from 0.84172
# Epoch 9/250
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009997839541429343.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4394 - accuracy: 0.8365 - val_loss: 0.3660 - val_accuracy: 0.8649
#
# Epoch 00009: val_accuracy improved from 0.84172 to 0.86494, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 10/250
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009997299952403975.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4161 - accuracy: 0.8429 - val_loss: 0.3457 - val_accuracy: 0.8715
#
# Epoch 00010: val_accuracy improved from 0.86494 to 0.87152, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 11/250
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009996699837517878.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4034 - accuracy: 0.8519 - val_loss: 0.3301 - val_accuracy: 0.8858
#
# Epoch 00011: val_accuracy improved from 0.87152 to 0.88584, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 12/250
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009996040361936833.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4067 - accuracy: 0.8513 - val_loss: 0.3824 - val_accuracy: 0.8630
#
# Epoch 00012: val_accuracy did not improve from 0.88584
# Epoch 13/250
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009995320362659848.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3821 - accuracy: 0.8606 - val_loss: 0.3466 - val_accuracy: 0.8746
#
# Epoch 00013: val_accuracy did not improve from 0.88584
# Epoch 14/250
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009994541004838694.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3769 - accuracy: 0.8631 - val_loss: 0.3586 - val_accuracy: 0.8746
#
# Epoch 00014: val_accuracy did not improve from 0.88584
# Epoch 15/250
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.000999370112548629.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3733 - accuracy: 0.8647 - val_loss: 0.3138 - val_accuracy: 0.8959
#
# Epoch 00015: val_accuracy improved from 0.88584 to 0.89590, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 16/250
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009992801889740382.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3674 - accuracy: 0.8620 - val_loss: 0.3872 - val_accuracy: 0.8611
#
# Epoch 00016: val_accuracy did not improve from 0.89590
# Epoch 17/250
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.000999184213462781.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3842 - accuracy: 0.8603 - val_loss: 0.3241 - val_accuracy: 0.8858
#
# Epoch 00017: val_accuracy did not improve from 0.89590
# Epoch 18/250
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009990823025272304.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3622 - accuracy: 0.8662 - val_loss: 0.3178 - val_accuracy: 0.8893
#
# Epoch 00018: val_accuracy did not improve from 0.89590
# Epoch 19/250
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.000998974456274212.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3698 - accuracy: 0.8613 - val_loss: 0.3289 - val_accuracy: 0.8847
#
# Epoch 00019: val_accuracy did not improve from 0.89590
# Epoch 20/250
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009988605584084975.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3618 - accuracy: 0.8635 - val_loss: 0.3354 - val_accuracy: 0.8808
#
# Epoch 00020: val_accuracy did not improve from 0.89590
# Epoch 21/250
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0009987407254403566.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3806 - accuracy: 0.8588 - val_loss: 0.3467 - val_accuracy: 0.8692
#
# Epoch 00021: val_accuracy did not improve from 0.89590
# Epoch 22/250
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0009986149574766072.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3551 - accuracy: 0.8696 - val_loss: 0.3588 - val_accuracy: 0.8750
#
# Epoch 00022: val_accuracy did not improve from 0.89590
# Epoch 23/250
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000998483138224109.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3472 - accuracy: 0.8750 - val_loss: 0.3064 - val_accuracy: 0.8963
#
# Epoch 00023: val_accuracy improved from 0.89590 to 0.89628, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 24/250
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.000998345384191028.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3339 - accuracy: 0.8763 - val_loss: 0.3105 - val_accuracy: 0.8897
#
# Epoch 00024: val_accuracy did not improve from 0.89628
# Epoch 25/250
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0009982016954841755.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3583 - accuracy: 0.8687 - val_loss: 0.3087 - val_accuracy: 0.8905
#
# Epoch 00025: val_accuracy did not improve from 0.89628
# Epoch 26/250
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0009980519558124969.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3365 - accuracy: 0.8769 - val_loss: 0.4123 - val_accuracy: 0.8735
#
# Epoch 00026: val_accuracy did not improve from 0.89628
# Epoch 27/250
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0009978962816820569.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3464 - accuracy: 0.8698 - val_loss: 0.3280 - val_accuracy: 0.8909
#
# Epoch 00027: val_accuracy did not improve from 0.89628
# Epoch 28/250
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0009977346731996585.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3461 - accuracy: 0.8708 - val_loss: 0.3245 - val_accuracy: 0.8882
#
# Epoch 00028: val_accuracy did not improve from 0.89628
# Epoch 29/250
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0009975671304721016.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3521 - accuracy: 0.8746 - val_loss: 0.3155 - val_accuracy: 0.8874
#
# Epoch 00029: val_accuracy did not improve from 0.89628
# Epoch 30/250
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0009973935372111155.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3654 - accuracy: 0.8638 - val_loss: 0.3354 - val_accuracy: 0.8820
#
# Epoch 00030: val_accuracy did not improve from 0.89628
# Epoch 31/250
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0009972140099199606.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3555 - accuracy: 0.8667 - val_loss: 0.3053 - val_accuracy: 0.8998
#
# Epoch 00031: val_accuracy improved from 0.89628 to 0.89977, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 32/250
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00099702854870543.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3435 - accuracy: 0.8762 - val_loss: 0.3252 - val_accuracy: 0.8851
#
# Epoch 00032: val_accuracy did not improve from 0.89977
# Epoch 33/250
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0009968371536743133.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3449 - accuracy: 0.8732 - val_loss: 0.3275 - val_accuracy: 0.8866
#
# Epoch 00033: val_accuracy did not improve from 0.89977
# Epoch 34/250
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0009966398249333986.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3608 - accuracy: 0.8665 - val_loss: 0.3243 - val_accuracy: 0.8858
#
# Epoch 00034: val_accuracy did not improve from 0.89977
# Epoch 35/250
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0009964365625894703.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3378 - accuracy: 0.8762 - val_loss: 0.3095 - val_accuracy: 0.8924
#
# Epoch 00035: val_accuracy did not improve from 0.89977
# Epoch 36/250
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0009962273667493114.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3446 - accuracy: 0.8724 - val_loss: 0.3395 - val_accuracy: 0.8820
#
# Epoch 00036: val_accuracy did not improve from 0.89977
# Epoch 37/250
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0009960122375197015.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3504 - accuracy: 0.8757 - val_loss: 0.3194 - val_accuracy: 0.8990
#
# Epoch 00037: val_accuracy did not improve from 0.89977
# Epoch 38/250
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.000995791175007418.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3581 - accuracy: 0.8681 - val_loss: 0.4667 - val_accuracy: 0.8332
#
# Epoch 00038: val_accuracy did not improve from 0.89977
# Epoch 39/250
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0009955641793192357.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4380 - accuracy: 0.8376 - val_loss: 0.3812 - val_accuracy: 0.8638
#
# Epoch 00039: val_accuracy did not improve from 0.89977
# Epoch 40/250
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0009953312505619261.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3859 - accuracy: 0.8616 - val_loss: 0.3323 - val_accuracy: 0.8878
#
# Epoch 00040: val_accuracy did not improve from 0.89977
# Epoch 41/250
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00099509238884226.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3496 - accuracy: 0.8714 - val_loss: 0.3179 - val_accuracy: 0.8901
#
# Epoch 00041: val_accuracy did not improve from 0.89977
# Epoch 42/250
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0009948477106536942.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4086 - accuracy: 0.8514 - val_loss: 0.3107 - val_accuracy: 0.8955
#
# Epoch 00042: val_accuracy did not improve from 0.89977
# Epoch 43/250
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0009945970997149067.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3397 - accuracy: 0.8786 - val_loss: 0.3068 - val_accuracy: 0.8963
#
# Epoch 00043: val_accuracy did not improve from 0.89977
# Epoch 44/250
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.000994340556132659.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3447 - accuracy: 0.8737 - val_loss: 0.3278 - val_accuracy: 0.8854
#
# Epoch 00044: val_accuracy did not improve from 0.89977
# Epoch 45/250
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0009940780800137112.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3490 - accuracy: 0.8746 - val_loss: 0.3198 - val_accuracy: 0.8959
#
# Epoch 00045: val_accuracy did not improve from 0.89977
# Epoch 46/250
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.000993809787848718.
#  - 2s 5ms/step - loss: 0.3559 - accuracy: 0.8694 - val_loss: 0.3111 - val_accuracy: 0.8955
#
# Epoch 00046: val_accuracy did not improve from 0.89977
# Epoch 47/250
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0009935355633591389.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3634 - accuracy: 0.8641 - val_loss: 0.3151 - val_accuracy: 0.9040
#
# Epoch 00047: val_accuracy improved from 0.89977 to 0.90402, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 48/250
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0009932555230342279.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3499 - accuracy: 0.8728 - val_loss: 0.3586 - val_accuracy: 0.8765
#
# Epoch 00048: val_accuracy did not improve from 0.90402
# Epoch 49/250
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.000992969550596836.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3463 - accuracy: 0.8755 - val_loss: 0.3026 - val_accuracy: 0.8947
#
# Epoch 00049: val_accuracy did not improve from 0.90402
# Epoch 50/250
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.00099267764615371.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3425 - accuracy: 0.8772 - val_loss: 0.3151 - val_accuracy: 0.8928
#
# Epoch 00050: val_accuracy did not improve from 0.90402
# Epoch 51/250
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0009923799261920014.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3630 - accuracy: 0.8664 - val_loss: 0.3190 - val_accuracy: 0.8862
#
# Epoch 00051: val_accuracy did not improve from 0.90402
# Epoch 52/250
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0009920763908163577.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4036 - accuracy: 0.8488 - val_loss: 0.4031 - val_accuracy: 0.8495
#
# Epoch 00052: val_accuracy did not improve from 0.90402
# Epoch 53/250
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.000991766923752412.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3704 - accuracy: 0.8651 - val_loss: 0.3221 - val_accuracy: 0.8947
#
# Epoch 00053: val_accuracy did not improve from 0.90402
# Epoch 54/250
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0009914516414852145.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3449 - accuracy: 0.8745 - val_loss: 0.3448 - val_accuracy: 0.8878
#
# Epoch 00054: val_accuracy did not improve from 0.90402
# Epoch 55/250
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0009911305441194047.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3489 - accuracy: 0.8752 - val_loss: 0.3076 - val_accuracy: 0.8974
#
# Epoch 00055: val_accuracy did not improve from 0.90402
# Epoch 56/250
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0009908036317596203.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3466 - accuracy: 0.8756 - val_loss: 0.3352 - val_accuracy: 0.8835
#
# Epoch 00056: val_accuracy did not improve from 0.90402
# Epoch 57/250
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.000990470788134276.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3375 - accuracy: 0.8785 - val_loss: 0.3211 - val_accuracy: 0.8893
#
# Epoch 00057: val_accuracy did not improve from 0.90402
# Epoch 58/250
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0009901321297256195.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3265 - accuracy: 0.8821 - val_loss: 0.3182 - val_accuracy: 0.8928
#
# Epoch 00058: val_accuracy did not improve from 0.90402
# Epoch 59/250
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.000989787656638281.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3303 - accuracy: 0.8799 - val_loss: 0.3194 - val_accuracy: 0.8916
#
# Epoch 00059: val_accuracy did not improve from 0.90402
# Epoch 60/250
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0009894373689768876.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3462 - accuracy: 0.8722 - val_loss: 0.3464 - val_accuracy: 0.8800
#
# Epoch 00060: val_accuracy did not improve from 0.90402
# Epoch 61/250
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0009890812668460636.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3398 - accuracy: 0.8796 - val_loss: 0.3127 - val_accuracy: 0.8951
#
# Epoch 00061: val_accuracy did not improve from 0.90402
# Epoch 62/250
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.000988719350350431.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3454 - accuracy: 0.8741 - val_loss: 0.4158 - val_accuracy: 0.8437
#
# Epoch 00062: val_accuracy did not improve from 0.90402
# Epoch 63/250
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0009883517359666417.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3444 - accuracy: 0.8783 - val_loss: 0.5381 - val_accuracy: 0.8402
#
# Epoch 00063: val_accuracy did not improve from 0.90402
# Epoch 64/250
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.000987978307425885.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3520 - accuracy: 0.8703 - val_loss: 0.3161 - val_accuracy: 0.8897
#
# Epoch 00064: val_accuracy did not improve from 0.90402
# Epoch 65/250
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0009875990648327752.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3382 - accuracy: 0.8751 - val_loss: 0.3056 - val_accuracy: 0.8971
#
# Epoch 00065: val_accuracy did not improve from 0.90402
# Epoch 66/250
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0009872140082919252.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3350 - accuracy: 0.8778 - val_loss: 0.3773 - val_accuracy: 0.8777
#
# Epoch 00066: val_accuracy did not improve from 0.90402
# Epoch 67/250
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0009868232542771835.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3622 - accuracy: 0.8659 - val_loss: 0.3700 - val_accuracy: 0.8700
#
# Epoch 00067: val_accuracy did not improve from 0.90402
# Epoch 68/250
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.000986426686522522.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3474 - accuracy: 0.8742 - val_loss: 0.3250 - val_accuracy: 0.8924
#
# Epoch 00068: val_accuracy did not improve from 0.90402
# Epoch 69/250
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0009860244215003896.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3516 - accuracy: 0.8714 - val_loss: 0.2997 - val_accuracy: 0.9013
#
# Epoch 00069: val_accuracy did not improve from 0.90402
# Epoch 70/250
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0009856163429461482.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3336 - accuracy: 0.8795 - val_loss: 0.3487 - val_accuracy: 0.8874
#
# Epoch 00070: val_accuracy did not improve from 0.90402
# Epoch 71/250
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.0009852025673308454.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3451 - accuracy: 0.8708 - val_loss: 0.3326 - val_accuracy: 0.8843
#
# Epoch 00071: val_accuracy did not improve from 0.90402
# Epoch 72/250
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.000984783094756985.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3453 - accuracy: 0.8761 - val_loss: 0.3185 - val_accuracy: 0.9005
#
# Epoch 00072: val_accuracy did not improve from 0.90402
# Epoch 73/250
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.0009843578089620156.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3374 - accuracy: 0.8791 - val_loss: 0.3542 - val_accuracy: 0.8696
#
# Epoch 00073: val_accuracy did not improve from 0.90402
# Epoch 74/250
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.0009839268264148838.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3580 - accuracy: 0.8677 - val_loss: 0.2935 - val_accuracy: 0.8994
#
# Epoch 00074: val_accuracy did not improve from 0.90402
# Epoch 75/250
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.0009834901472180852.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4204 - accuracy: 0.8444 - val_loss: 0.3865 - val_accuracy: 0.8700
#
# Epoch 00075: val_accuracy did not improve from 0.90402
# Epoch 76/250
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0009830477714741139.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4005 - accuracy: 0.8503 - val_loss: 0.3388 - val_accuracy: 0.8878
#
# Epoch 00076: val_accuracy did not improve from 0.90402
# Epoch 77/250
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.0009825996992854607.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3355 - accuracy: 0.8789 - val_loss: 0.3147 - val_accuracy: 0.8936
#
# Epoch 00077: val_accuracy did not improve from 0.90402
# Epoch 78/250
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0009821459307546145.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3371 - accuracy: 0.8769 - val_loss: 0.3636 - val_accuracy: 0.8862
#
# Epoch 00078: val_accuracy did not improve from 0.90402
# Epoch 79/250
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.000981686465984061.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3369 - accuracy: 0.8771 - val_loss: 0.3439 - val_accuracy: 0.8858
#
# Epoch 00079: val_accuracy did not improve from 0.90402
# Epoch 80/250
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.0009812214214364515.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3225 - accuracy: 0.8847 - val_loss: 0.3381 - val_accuracy: 0.8843
#
# Epoch 00080: val_accuracy did not improve from 0.90402
# Epoch 81/250
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0009807506808527046.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3192 - accuracy: 0.8838 - val_loss: 0.4025 - val_accuracy: 0.8754
#
# Epoch 00081: val_accuracy did not improve from 0.90402
# Epoch 82/250
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.000980274244335299.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3572 - accuracy: 0.8691 - val_loss: 0.3287 - val_accuracy: 0.8928
#
# Epoch 00082: val_accuracy did not improve from 0.90402
# Epoch 83/250
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.0009797922283447844.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3374 - accuracy: 0.8764 - val_loss: 0.2985 - val_accuracy: 0.9036
#
# Epoch 00083: val_accuracy did not improve from 0.90402
# Epoch 84/250
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.0009793045166241656.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3335 - accuracy: 0.8763 - val_loss: 0.3047 - val_accuracy: 0.8967
#
# Epoch 00084: val_accuracy did not improve from 0.90402
# Epoch 85/250
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.0009788112256325927.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3249 - accuracy: 0.8809 - val_loss: 0.3080 - val_accuracy: 0.8951
#
# Epoch 00085: val_accuracy did not improve from 0.90402
# Epoch 86/250
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.0009783122391144607.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3216 - accuracy: 0.8839 - val_loss: 0.3627 - val_accuracy: 0.8835
#
# Epoch 00086: val_accuracy did not improve from 0.90402
# Epoch 87/250
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.0009778076735275187.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3399 - accuracy: 0.8775 - val_loss: 0.3344 - val_accuracy: 0.8901
#
# Epoch 00087: val_accuracy did not improve from 0.90402
# Epoch 88/250
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.0009772975289721376.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3280 - accuracy: 0.8807 - val_loss: 0.3295 - val_accuracy: 0.8905
#
# Epoch 00088: val_accuracy did not improve from 0.90402
# Epoch 89/250
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.0009767818055486854.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3939 - accuracy: 0.8552 - val_loss: 0.9705 - val_accuracy: 0.7554
#
# Epoch 00089: val_accuracy did not improve from 0.90402
# Epoch 90/250
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.000976260503357529.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.5192 - accuracy: 0.8065 - val_loss: 0.3815 - val_accuracy: 0.8793
#
# Epoch 00090: val_accuracy did not improve from 0.90402
# Epoch 91/250
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.0009757336224990315.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3335 - accuracy: 0.8808 - val_loss: 0.3258 - val_accuracy: 0.8932
#
# Epoch 00091: val_accuracy did not improve from 0.90402
# Epoch 92/250
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0009752011630735541.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4045 - accuracy: 0.8468 - val_loss: 0.3778 - val_accuracy: 0.8680
#
# Epoch 00092: val_accuracy did not improve from 0.90402
# Epoch 93/250
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0009746631251814555.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3664 - accuracy: 0.8657 - val_loss: 0.3667 - val_accuracy: 0.8800
#
# Epoch 00093: val_accuracy did not improve from 0.90402
# Epoch 94/250
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0009741195670982918.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3391 - accuracy: 0.8779 - val_loss: 0.3219 - val_accuracy: 0.8897
#
# Epoch 00094: val_accuracy did not improve from 0.90402
# Epoch 95/250
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0009735704889233699.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3216 - accuracy: 0.8840 - val_loss: 0.3205 - val_accuracy: 0.8885
#
# Epoch 00095: val_accuracy did not improve from 0.90402
# Epoch 96/250
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.000973015890755995.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3642 - accuracy: 0.8690 - val_loss: 0.3203 - val_accuracy: 0.8882
#
# Epoch 00096: val_accuracy did not improve from 0.90402
# Epoch 97/250
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0009724557726954699.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3189 - accuracy: 0.8860 - val_loss: 0.3283 - val_accuracy: 0.8874
#
# Epoch 00097: val_accuracy did not improve from 0.90402
# Epoch 98/250
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0009718901348410946.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3180 - accuracy: 0.8836 - val_loss: 0.3294 - val_accuracy: 0.8916
#
# Epoch 00098: val_accuracy did not improve from 0.90402
# Epoch 99/250
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0009713189772921672.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3523 - accuracy: 0.8688 - val_loss: 0.3121 - val_accuracy: 0.8947
#
# Epoch 00099: val_accuracy did not improve from 0.90402
# Epoch 100/250
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0009707423583210894.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3271 - accuracy: 0.8811 - val_loss: 0.3381 - val_accuracy: 0.8835
#
# Epoch 00100: val_accuracy did not improve from 0.90402
# Epoch 101/250
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 0.0009701602780261077.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3194 - accuracy: 0.8835 - val_loss: 0.2865 - val_accuracy: 0.8951
#
# Epoch 00101: val_accuracy did not improve from 0.90402
# Epoch 102/250
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 0.0009695727365054662.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3212 - accuracy: 0.8823 - val_loss: 0.3262 - val_accuracy: 0.8889
#
# Epoch 00102: val_accuracy did not improve from 0.90402
# Epoch 103/250
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 0.0009689797338574073.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3179 - accuracy: 0.8841 - val_loss: 0.3153 - val_accuracy: 0.8924
#
# Epoch 00103: val_accuracy did not improve from 0.90402
# Epoch 104/250
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 0.0009683812701801704.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3972 - accuracy: 0.8539 - val_loss: 0.3734 - val_accuracy: 0.8661
#
# Epoch 00104: val_accuracy did not improve from 0.90402
# Epoch 105/250
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 0.0009677774037433545.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3439 - accuracy: 0.8720 - val_loss: 0.3473 - val_accuracy: 0.8854
#
# Epoch 00105: val_accuracy did not improve from 0.90402
# Epoch 106/250
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 0.0009671680764731351.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3130 - accuracy: 0.8888 - val_loss: 0.3162 - val_accuracy: 0.8874
#
# Epoch 00106: val_accuracy did not improve from 0.90402
# Epoch 107/250
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 0.0009665533466384088.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3162 - accuracy: 0.8841 - val_loss: 0.3070 - val_accuracy: 0.8955
#
# Epoch 00107: val_accuracy did not improve from 0.90402
# Epoch 108/250
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 0.0009659332143363598.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3179 - accuracy: 0.8814 - val_loss: 0.3040 - val_accuracy: 0.8913
#
# Epoch 00108: val_accuracy did not improve from 0.90402
# Epoch 109/250
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 0.0009653076796641693.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3083 - accuracy: 0.8875 - val_loss: 0.3088 - val_accuracy: 0.8974
#
# Epoch 00109: val_accuracy did not improve from 0.90402
# Epoch 110/250
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.0009646768008886345.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3128 - accuracy: 0.8836 - val_loss: 0.4278 - val_accuracy: 0.8731
#
# Epoch 00110: val_accuracy did not improve from 0.90402
# Epoch 111/250
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.0009640405199366162.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3280 - accuracy: 0.8793 - val_loss: 0.3331 - val_accuracy: 0.8808
#
# Epoch 00111: val_accuracy did not improve from 0.90402
# Epoch 112/250
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.0009633988950742099.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3179 - accuracy: 0.8842 - val_loss: 0.3028 - val_accuracy: 0.8998
#
# Epoch 00112: val_accuracy did not improve from 0.90402
# Epoch 113/250
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.0009627519263975411.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3223 - accuracy: 0.8820 - val_loss: 0.3370 - val_accuracy: 0.8885
#
# Epoch 00113: val_accuracy did not improve from 0.90402
# Epoch 114/250
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.0009620996140027332.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3226 - accuracy: 0.8857 - val_loss: 0.3432 - val_accuracy: 0.8943
#
# Epoch 00114: val_accuracy did not improve from 0.90402
# Epoch 115/250
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.0009614420161537816.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3347 - accuracy: 0.8796 - val_loss: 0.3245 - val_accuracy: 0.8885
#
# Epoch 00115: val_accuracy did not improve from 0.90402
# Epoch 116/250
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.0009607790747782333.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3202 - accuracy: 0.8824 - val_loss: 0.3227 - val_accuracy: 0.8955
#
# Epoch 00116: val_accuracy did not improve from 0.90402
# Epoch 117/250
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.0009601108481393819.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3371 - accuracy: 0.8741 - val_loss: 0.3051 - val_accuracy: 0.9009
#
# Epoch 00117: val_accuracy did not improve from 0.90402
# Epoch 118/250
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.0009594373363322951.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3056 - accuracy: 0.8873 - val_loss: 0.3503 - val_accuracy: 0.8785
#
# Epoch 00118: val_accuracy did not improve from 0.90402
# Epoch 119/250
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.0009587585394520386.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3200 - accuracy: 0.8803 - val_loss: 0.3114 - val_accuracy: 0.8955
#
# Epoch 00119: val_accuracy did not improve from 0.90402
# Epoch 120/250
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.0009580744575936758.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3032 - accuracy: 0.8864 - val_loss: 0.3368 - val_accuracy: 0.8820
#
# Epoch 00120: val_accuracy did not improve from 0.90402
# Epoch 121/250
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.0009573851490180496.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3100 - accuracy: 0.8874 - val_loss: 4.8487 - val_accuracy: 0.5712
#
# Epoch 00121: val_accuracy did not improve from 0.90402
# Epoch 122/250
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.0009566906138191726.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.5492 - accuracy: 0.7985 - val_loss: 0.5923 - val_accuracy: 0.7732
#
# Epoch 00122: val_accuracy did not improve from 0.90402
# Epoch 123/250
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.0009559908520910553.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4968 - accuracy: 0.8148 - val_loss: 0.4827 - val_accuracy: 0.8375
#
# Epoch 00123: val_accuracy did not improve from 0.90402
# Epoch 124/250
#
# Epoch 00124: LearningRateScheduler reducing learning rate to 0.0009552858639277056.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4493 - accuracy: 0.8355 - val_loss: 0.4201 - val_accuracy: 0.8471
#
# Epoch 00124: val_accuracy did not improve from 0.90402
# Epoch 125/250
#
# Epoch 00125: LearningRateScheduler reducing learning rate to 0.0009545756494231294.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4325 - accuracy: 0.8471 - val_loss: 0.3958 - val_accuracy: 0.8553
#
# Epoch 00125: val_accuracy did not improve from 0.90402
# Epoch 126/250
#
# Epoch 00126: LearningRateScheduler reducing learning rate to 0.0009538602668353685.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4430 - accuracy: 0.8377 - val_loss: 0.4188 - val_accuracy: 0.8491
#
# Epoch 00126: val_accuracy did not improve from 0.90402
# Epoch 127/250
#
# Epoch 00127: LearningRateScheduler reducing learning rate to 0.0009531397162573779.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4122 - accuracy: 0.8462 - val_loss: 0.4177 - val_accuracy: 0.8483
#
# Epoch 00127: val_accuracy did not improve from 0.90402
# Epoch 128/250
#
# Epoch 00128: LearningRateScheduler reducing learning rate to 0.0009524139977821108.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4131 - accuracy: 0.8488 - val_loss: 0.4293 - val_accuracy: 0.8444
#
# Epoch 00128: val_accuracy did not improve from 0.90402
# Epoch 129/250
#
# Epoch 00129: LearningRateScheduler reducing learning rate to 0.0009516831115025175.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4388 - accuracy: 0.8353 - val_loss: 0.4002 - val_accuracy: 0.8587
#
# Epoch 00129: val_accuracy did not improve from 0.90402
# Epoch 130/250
#
# Epoch 00130: LearningRateScheduler reducing learning rate to 0.0009509470575115472.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4109 - accuracy: 0.8515 - val_loss: 0.3710 - val_accuracy: 0.8622
#
# Epoch 00130: val_accuracy did not improve from 0.90402
# Epoch 131/250
#
# Epoch 00131: LearningRateScheduler reducing learning rate to 0.0009502058940644402.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4141 - accuracy: 0.8477 - val_loss: 0.4136 - val_accuracy: 0.8607
#
# Epoch 00131: val_accuracy did not improve from 0.90402
# Epoch 132/250
#
# Epoch 00132: LearningRateScheduler reducing learning rate to 0.0009494596212530944.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4265 - accuracy: 0.8416 - val_loss: 0.3718 - val_accuracy: 0.8584
#
# Epoch 00132: val_accuracy did not improve from 0.90402
# Epoch 133/250
#
# Epoch 00133: LearningRateScheduler reducing learning rate to 0.0009487082391694056.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4291 - accuracy: 0.8377 - val_loss: 0.3957 - val_accuracy: 0.8638
#
# Epoch 00133: val_accuracy did not improve from 0.90402
# Epoch 134/250
#
# Epoch 00134: LearningRateScheduler reducing learning rate to 0.0009479517479052673.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3894 - accuracy: 0.8589 - val_loss: 0.4260 - val_accuracy: 0.8529
#
# Epoch 00134: val_accuracy did not improve from 0.90402
# Epoch 135/250
#
# Epoch 00135: LearningRateScheduler reducing learning rate to 0.0009471902057134707.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4223 - accuracy: 0.8434 - val_loss: 0.4005 - val_accuracy: 0.8634
#
# Epoch 00135: val_accuracy did not improve from 0.90402
# Epoch 136/250
#
# Epoch 00136: LearningRateScheduler reducing learning rate to 0.0009464236126848586.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3879 - accuracy: 0.8514 - val_loss: 0.3551 - val_accuracy: 0.8711
#
# Epoch 00136: val_accuracy did not improve from 0.90402
# Epoch 137/250
#
# Epoch 00137: LearningRateScheduler reducing learning rate to 0.0009456519689102723.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3924 - accuracy: 0.8533 - val_loss: 0.3720 - val_accuracy: 0.8719
#
# Epoch 00137: val_accuracy did not improve from 0.90402
# Epoch 138/250
#
# Epoch 00138: LearningRateScheduler reducing learning rate to 0.0009448752744805501.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3740 - accuracy: 0.8609 - val_loss: 0.3760 - val_accuracy: 0.8615
#
# Epoch 00138: val_accuracy did not improve from 0.90402
# Epoch 139/250
#
# Epoch 00139: LearningRateScheduler reducing learning rate to 0.0009440935876460338.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3895 - accuracy: 0.8554 - val_loss: 0.3603 - val_accuracy: 0.8758
#
# Epoch 00139: val_accuracy did not improve from 0.90402
# Epoch 140/250
#
# Epoch 00140: LearningRateScheduler reducing learning rate to 0.0009433068503373555.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3711 - accuracy: 0.8657 - val_loss: 0.4127 - val_accuracy: 0.8460
#
# Epoch 00140: val_accuracy did not improve from 0.90402
# Epoch 141/250
#
# Epoch 00141: LearningRateScheduler reducing learning rate to 0.0009425151208041551.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3906 - accuracy: 0.8560 - val_loss: 0.3810 - val_accuracy: 0.8591
#
# Epoch 00141: val_accuracy did not improve from 0.90402
# Epoch 142/250
#
# Epoch 00142: LearningRateScheduler reducing learning rate to 0.0009417183991362164.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3794 - accuracy: 0.8603 - val_loss: 0.3944 - val_accuracy: 0.8595
#
# Epoch 00142: val_accuracy did not improve from 0.90402
# Epoch 143/250
#
# Epoch 00143: LearningRateScheduler reducing learning rate to 0.0009409167435814314.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3926 - accuracy: 0.8544 - val_loss: 0.3605 - val_accuracy: 0.8762
#
# Epoch 00143: val_accuracy did not improve from 0.90402
# Epoch 144/250
#
# Epoch 00144: LearningRateScheduler reducing learning rate to 0.0009401101542285345.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3932 - accuracy: 0.8527 - val_loss: 0.4242 - val_accuracy: 0.8653
#
# Epoch 00144: val_accuracy did not improve from 0.90402
# Epoch 145/250
#
# Epoch 00145: LearningRateScheduler reducing learning rate to 0.0009392985730088441.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3877 - accuracy: 0.8523 - val_loss: 0.3446 - val_accuracy: 0.8738
#
# Epoch 00145: val_accuracy did not improve from 0.90402
# Epoch 146/250
#
# Epoch 00146: LearningRateScheduler reducing learning rate to 0.0009384821163262644.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3669 - accuracy: 0.8626 - val_loss: 0.3434 - val_accuracy: 0.8835
#
# Epoch 00146: val_accuracy did not improve from 0.90402
# Epoch 147/250
#
# Epoch 00147: LearningRateScheduler reducing learning rate to 0.000937660726111761.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3899 - accuracy: 0.8543 - val_loss: 0.5872 - val_accuracy: 0.7953
#
# Epoch 00147: val_accuracy did not improve from 0.90402
# Epoch 148/250
#
# Epoch 00148: LearningRateScheduler reducing learning rate to 0.0009368344606104266.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3878 - accuracy: 0.8563 - val_loss: 0.3558 - val_accuracy: 0.8715
#
# Epoch 00148: val_accuracy did not improve from 0.90402
# Epoch 149/250
#
# Epoch 00149: LearningRateScheduler reducing learning rate to 0.00093600326175392.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3700 - accuracy: 0.8631 - val_loss: 0.3667 - val_accuracy: 0.8707
#
# Epoch 00149: val_accuracy did not improve from 0.90402
# Epoch 150/250
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 0.0009351672459423017.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3658 - accuracy: 0.8665 - val_loss: 0.3821 - val_accuracy: 0.8746
#
# Epoch 00150: val_accuracy did not improve from 0.90402
# Epoch 151/250
#
# Epoch 00151: LearningRateScheduler reducing learning rate to 0.0009343263551068779.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3715 - accuracy: 0.8630 - val_loss: 0.3983 - val_accuracy: 0.8676
#
# Epoch 00151: val_accuracy did not improve from 0.90402
# Epoch 00151: early stopping
# Model: "ExtAudioDataModelQAT"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quantize_layer (QuantizeLaye (None, 40, 49, 1)         3
# _________________________________________________________________
# quant_conv2d (QuantizeWrappe (None, 17, 20, 8)         667
# _________________________________________________________________
# quant_max_pooling2d (Quantiz (None, 8, 10, 8)          1
# _________________________________________________________________
# quant_dropout (QuantizeWrapp (None, 8, 10, 8)          1
# _________________________________________________________________
# quant_flatten (QuantizeWrapp (None, 640)               1
# _________________________________________________________________
# quant_dense (QuantizeWrapper (None, 4)                 2569
# =================================================================
# Total params: 3,242
# Trainable params: 3,212
# Non-trainable params: 30
# _________________________________________________________________
# Epoch 1/250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3678 - accuracy: 0.8616 - val_loss: 0.3408 - val_accuracy: 0.8796
#
# Epoch 00001: val_accuracy did not improve from 0.90402
# Epoch 2/250
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009999940475331661.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3834 - accuracy: 0.8560 - val_loss: 0.3374 - val_accuracy: 0.8785
#
# Epoch 00002: val_accuracy did not improve from 0.90402
# Epoch 3/250
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000999981994116787.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3618 - accuracy: 0.8721 - val_loss: 0.3544 - val_accuracy: 0.8870
#
# Epoch 00003: val_accuracy did not improve from 0.90402
# Epoch 4/250
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009999640037705003.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3445 - accuracy: 0.8740 - val_loss: 0.3640 - val_accuracy: 0.8707
#
# Epoch 00004: val_accuracy did not improve from 0.90402
# Epoch 5/250
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009999399601886404.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3602 - accuracy: 0.8718 - val_loss: 0.3608 - val_accuracy: 0.8769
#
# Epoch 00005: val_accuracy did not improve from 0.90402
# Epoch 6/250
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.000999909979891992.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3506 - accuracy: 0.8746 - val_loss: 0.3016 - val_accuracy: 0.9009
#
# Epoch 00006: val_accuracy did not improve from 0.90402
# Epoch 7/250
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009998739465762805.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3530 - accuracy: 0.8730 - val_loss: 0.3327 - val_accuracy: 0.8916
#
# Epoch 00007: val_accuracy did not improve from 0.90402
# Epoch 8/250
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009998319767608886.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3905 - accuracy: 0.8542 - val_loss: 0.6602 - val_accuracy: 0.7515
#
# Epoch 00008: val_accuracy did not improve from 0.90402
# Epoch 9/250
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009997839541429343.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3681 - accuracy: 0.8680 - val_loss: 0.2956 - val_accuracy: 0.9060
#
# Epoch 00009: val_accuracy improved from 0.90402 to 0.90596, saving model to /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/checkpoints/ExtAudioDataModelQAT.hdf5
# Epoch 10/250
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009997299952403975.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3817 - accuracy: 0.8596 - val_loss: 0.3649 - val_accuracy: 0.8684
#
# Epoch 00010: val_accuracy did not improve from 0.90596
# Epoch 11/250
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009996699837517878.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3581 - accuracy: 0.8717 - val_loss: 0.3041 - val_accuracy: 0.8967
#
# Epoch 00011: val_accuracy did not improve from 0.90596
# Epoch 12/250
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009996040361936833.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3519 - accuracy: 0.8722 - val_loss: 0.3286 - val_accuracy: 0.8897
#
# Epoch 00012: val_accuracy did not improve from 0.90596
# Epoch 13/250
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009995320362659848.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3323 - accuracy: 0.8793 - val_loss: 0.3383 - val_accuracy: 0.8804
#
# Epoch 00013: val_accuracy did not improve from 0.90596
# Epoch 14/250
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009994541004838694.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3371 - accuracy: 0.8797 - val_loss: 0.3304 - val_accuracy: 0.8889
#
# Epoch 00014: val_accuracy did not improve from 0.90596
# Epoch 15/250
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.000999370112548629.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3475 - accuracy: 0.8769 - val_loss: 0.3138 - val_accuracy: 0.8940
#
# Epoch 00015: val_accuracy did not improve from 0.90596
# Epoch 16/250
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009992801889740382.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3468 - accuracy: 0.8728 - val_loss: 0.3053 - val_accuracy: 0.9044
#
# Epoch 00016: val_accuracy did not improve from 0.90596
# Epoch 17/250
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.000999184213462781.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3425 - accuracy: 0.8770 - val_loss: 0.3147 - val_accuracy: 0.8974
#
# Epoch 00017: val_accuracy did not improve from 0.90596
# Epoch 18/250
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009990823025272304.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3387 - accuracy: 0.8761 - val_loss: 0.3106 - val_accuracy: 0.8971
#
# Epoch 00018: val_accuracy did not improve from 0.90596
# Epoch 19/250
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.000998974456274212.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3502 - accuracy: 0.8724 - val_loss: 0.3258 - val_accuracy: 0.8854
#
# Epoch 00019: val_accuracy did not improve from 0.90596
# Epoch 20/250
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009988605584084975.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3388 - accuracy: 0.8785 - val_loss: 0.3382 - val_accuracy: 0.8777
#
# Epoch 00020: val_accuracy did not improve from 0.90596
# Epoch 21/250
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0009987407254403566.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.4229 - accuracy: 0.8356 - val_loss: 0.3895 - val_accuracy: 0.8591
#
# Epoch 00021: val_accuracy did not improve from 0.90596
# Epoch 22/250
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0009986149574766072.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4610 - accuracy: 0.8264 - val_loss: 0.3528 - val_accuracy: 0.8750
#
# Epoch 00022: val_accuracy did not improve from 0.90596
# Epoch 23/250
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.000998483138224109.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4234 - accuracy: 0.8430 - val_loss: 0.3412 - val_accuracy: 0.8843
#
# Epoch 00023: val_accuracy did not improve from 0.90596
# Epoch 24/250
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.000998345384191028.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.4330 - accuracy: 0.8371 - val_loss: 0.4270 - val_accuracy: 0.8440
#
# Epoch 00024: val_accuracy did not improve from 0.90596
# Epoch 25/250
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0009982016954841755.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4000 - accuracy: 0.8533 - val_loss: 0.3975 - val_accuracy: 0.8727
#
# Epoch 00025: val_accuracy did not improve from 0.90596
# Epoch 26/250
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0009980519558124969.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3453 - accuracy: 0.8752 - val_loss: 0.3336 - val_accuracy: 0.8824
#
# Epoch 00026: val_accuracy did not improve from 0.90596
# Epoch 27/250
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0009978962816820569.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3469 - accuracy: 0.8729 - val_loss: 0.4128 - val_accuracy: 0.8738
#
# Epoch 00027: val_accuracy did not improve from 0.90596
# Epoch 28/250
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0009977346731996585.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3516 - accuracy: 0.8734 - val_loss: 0.3680 - val_accuracy: 0.8657
#
# Epoch 00028: val_accuracy did not improve from 0.90596
# Epoch 29/250
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0009975671304721016.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4296 - accuracy: 0.8396 - val_loss: 0.3633 - val_accuracy: 0.8653
#
# Epoch 00029: val_accuracy did not improve from 0.90596
# Epoch 30/250
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0009973935372111155.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4183 - accuracy: 0.8428 - val_loss: 0.3982 - val_accuracy: 0.8568
#
# Epoch 00030: val_accuracy did not improve from 0.90596
# Epoch 31/250
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0009972140099199606.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4166 - accuracy: 0.8468 - val_loss: 0.3873 - val_accuracy: 0.8518
#
# Epoch 00031: val_accuracy did not improve from 0.90596
# Epoch 32/250
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00099702854870543.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3938 - accuracy: 0.8544 - val_loss: 0.3312 - val_accuracy: 0.8951
#
# Epoch 00032: val_accuracy did not improve from 0.90596
# Epoch 33/250
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0009968371536743133.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3342 - accuracy: 0.8763 - val_loss: 0.3122 - val_accuracy: 0.8955
#
# Epoch 00033: val_accuracy did not improve from 0.90596
# Epoch 34/250
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0009966398249333986.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3307 - accuracy: 0.8807 - val_loss: 0.3390 - val_accuracy: 0.8843
#
# Epoch 00034: val_accuracy did not improve from 0.90596
# Epoch 35/250
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0009964365625894703.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3219 - accuracy: 0.8828 - val_loss: 0.3092 - val_accuracy: 0.8932
#
# Epoch 00035: val_accuracy did not improve from 0.90596
# Epoch 36/250
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0009962273667493114.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3414 - accuracy: 0.8752 - val_loss: 0.3245 - val_accuracy: 0.8882
#
# Epoch 00036: val_accuracy did not improve from 0.90596
# Epoch 37/250
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0009960122375197015.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3331 - accuracy: 0.8779 - val_loss: 0.3096 - val_accuracy: 0.8994
#
# Epoch 00037: val_accuracy did not improve from 0.90596
# Epoch 38/250
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.000995791175007418.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3415 - accuracy: 0.8733 - val_loss: 0.2993 - val_accuracy: 0.9013
#
# Epoch 00038: val_accuracy did not improve from 0.90596
# Epoch 39/250
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0009955641793192357.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3428 - accuracy: 0.8772 - val_loss: 0.3946 - val_accuracy: 0.8591
#
# Epoch 00039: val_accuracy did not improve from 0.90596
# Epoch 40/250
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0009953312505619261.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3426 - accuracy: 0.8746 - val_loss: 0.3975 - val_accuracy: 0.8816
#
# Epoch 00040: val_accuracy did not improve from 0.90596
# Epoch 41/250
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00099509238884226.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3362 - accuracy: 0.8785 - val_loss: 0.3189 - val_accuracy: 0.8943
#
# Epoch 00041: val_accuracy did not improve from 0.90596
# Epoch 42/250
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0009948477106536942.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4284 - accuracy: 0.8431 - val_loss: 0.4157 - val_accuracy: 0.8526
#
# Epoch 00042: val_accuracy did not improve from 0.90596
# Epoch 43/250
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0009945970997149067.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4167 - accuracy: 0.8459 - val_loss: 0.3435 - val_accuracy: 0.8796
#
# Epoch 00043: val_accuracy did not improve from 0.90596
# Epoch 44/250
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.000994340556132659.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.4098 - accuracy: 0.8460 - val_loss: 0.3777 - val_accuracy: 0.8630
#
# Epoch 00044: val_accuracy did not improve from 0.90596
# Epoch 45/250
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0009940780800137112.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4019 - accuracy: 0.8492 - val_loss: 0.3447 - val_accuracy: 0.8808
#
# Epoch 00045: val_accuracy did not improve from 0.90596
# Epoch 46/250
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.000993809787848718.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.4303 - accuracy: 0.8397 - val_loss: 0.3870 - val_accuracy: 0.8491
#
# Epoch 00046: val_accuracy did not improve from 0.90596
# Epoch 47/250
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0009935355633591389.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4302 - accuracy: 0.8359 - val_loss: 0.3586 - val_accuracy: 0.8735
#
# Epoch 00047: val_accuracy did not improve from 0.90596
# Epoch 48/250
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0009932555230342279.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4149 - accuracy: 0.8410 - val_loss: 0.3409 - val_accuracy: 0.8746
#
# Epoch 00048: val_accuracy did not improve from 0.90596
# Epoch 49/250
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.000992969550596836.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4001 - accuracy: 0.8482 - val_loss: 0.4112 - val_accuracy: 0.8487
#
# Epoch 00049: val_accuracy did not improve from 0.90596
# Epoch 50/250
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.00099267764615371.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.4062 - accuracy: 0.8493 - val_loss: 0.3726 - val_accuracy: 0.8557
#
# Epoch 00050: val_accuracy did not improve from 0.90596
# Epoch 51/250
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0009923799261920014.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3940 - accuracy: 0.8544 - val_loss: 0.4294 - val_accuracy: 0.8537
#
# Epoch 00051: val_accuracy did not improve from 0.90596
# Epoch 52/250
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0009920763908163577.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3800 - accuracy: 0.8646 - val_loss: 0.3382 - val_accuracy: 0.8851
#
# Epoch 00052: val_accuracy did not improve from 0.90596
# Epoch 53/250
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.000991766923752412.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3482 - accuracy: 0.8795 - val_loss: 0.3531 - val_accuracy: 0.8777
#
# Epoch 00053: val_accuracy did not improve from 0.90596
# Epoch 54/250
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0009914516414852145.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.3319 - accuracy: 0.8829 - val_loss: 0.3769 - val_accuracy: 0.8777
#
# Epoch 00054: val_accuracy did not improve from 0.90596
# Epoch 55/250
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0009911305441194047.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4114 - accuracy: 0.8504 - val_loss: 0.3846 - val_accuracy: 0.8568
#
# Epoch 00055: val_accuracy did not improve from 0.90596
# Epoch 56/250
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0009908036317596203.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4072 - accuracy: 0.8505 - val_loss: 0.3817 - val_accuracy: 0.8649
#
# Epoch 00056: val_accuracy did not improve from 0.90596
# Epoch 57/250
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.000990470788134276.
# 324/324 [==============================] - 2s 5ms/step - loss: 0.4202 - accuracy: 0.8446 - val_loss: 0.3451 - val_accuracy: 0.8827
#
# Epoch 00057: val_accuracy did not improve from 0.90596
# Epoch 58/250
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0009901321297256195.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3858 - accuracy: 0.8592 - val_loss: 0.3454 - val_accuracy: 0.8758
#
# Epoch 00058: val_accuracy did not improve from 0.90596
# Epoch 59/250
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.000989787656638281.
# 324/324 [==============================] - 2s 6ms/step - loss: 0.3884 - accuracy: 0.8577 - val_loss: 0.3823 - val_accuracy: 0.8607
#
# Epoch 00059: val_accuracy did not improve from 0.90596
# Epoch 00059: early stopping

# %% [markdown]
# ## Visualización de historial de entrenamiento
#
# Se visualiza accuracy y loss de training y validation.

# %%
acc = tf.concat([history1.history["accuracy"], history2.history["accuracy"]], 0)
val_acc = tf.concat([history1.history["val_accuracy"], history2.history["val_accuracy"]], 0)

loss = tf.concat([history1.history["loss"], history2.history["loss"]], 0)
val_loss = tf.concat([history1.history["val_loss"], history2.history["val_loss"]], 0)

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title(f"Training and Validation Accuracy\nfor {model_name}")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.title(f"Training and Validation Loss\nfor {model_name}")

plt.savefig(f"{log_dir}/{model_name}_training_data.jpg")

plt.show()

# %% [markdown]
# ## Guardar modelo
# Guardamos el modelo entrenado para poder reutilizarlo en el futuro.

# %%
tf.keras.models.save_model(model, model_dir)
# Out:
# WARNING:absl:Found untraced functions such as conv2d_layer_call_fn, conv2d_layer_call_and_return_conditional_losses, dropout_layer_call_fn, dropout_layer_call_and_return_conditional_losses, flatten_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
# INFO:tensorflow:Assets written to: /home/daniel/PycharmProjects/tfg-tinyml/saved models/audio/tensorflow/ExtAudioDataModelQAT/assets
